# %% [markdown]
# ## Sample from raw data for preliminary analysis

# %%
def sample_partition():
    import pandas as pd
    import glob
    import os

    # Set pandas display options for better formatting
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', None)
    pd.set_option('display.max_colwidth', None)
    pd.set_option('display.float_format', lambda x: '%.3f' % x)
    
    
    # Get the first CSV.GZ file from part_1
    pattern = os.path.join("sample_data/part_1", "*.csv.gz")
    files = glob.glob(pattern)
    
    if not files:
        raise FileNotFoundError("No CSV.GZ files found in sample_data/part_1")
    
    # Take the first file found
    file_path = files[0]
    print(f"Sampling from: {file_path}")
    
    # Read 1000 random rows
    # Use chunksize for memory efficiency when dealing with large files
    df = pd.read_csv(file_path, compression='gzip', nrows=100000)
    
    return df

sample_df = sample_partition()
print(f"\nSample shape: {sample_df.shape}")
print("\nSample columns:")
print("- " + "\n- ".join(sample_df.columns.tolist()))
print("\nFirst few rows:")
print(sample_df.head().to_string())
# Out:
# Sampling from: sample_data/part_1/may_july_chunk_11.csv.gz
#
# Sample shape: (50000, 30)
#
# Sample columns:
# - id
# - text
# - url
# - epoch
# - media
# - retweetedTweet
# - retweetedTweetID
# - retweetedUserID
# - id_str
# - lang
# - rawContent
# - replyCount
# - retweetCount
# - likeCount
# - quoteCount
# - conversationId
# - conversationIdStr
# - hashtags
# - mentionedUsers
# - links
# - viewCount
# - quotedTweet
# - in_reply_to_screen_name
# - in_reply_to_status_id_str
# - in_reply_to_user_id_str
# - location
# - cash_app_handle
# - user
# - date
# - _type
#
# First few rows:
#                     id                                                                                                                                                                                                                                                                                       text                                                             url       epoch media  retweetedTweet  retweetedTweetID  retweetedUserID               id_str lang                                                                                                                                                                                                                                                                                 rawContent  replyCount  retweetCount  likeCount  quoteCount          conversationId       conversationIdStr hashtags                                                                                                                                    mentionedUsers links                                     viewCount  quotedTweet in_reply_to_screen_name  in_reply_to_status_id_str  in_reply_to_user_id_str  location  cash_app_handle                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                user  date  _type
# 0  1801321015319896315                                                                               @BidenHQ Thank you, PM Meloni, for shepherding our "lost little POTUS" back to the herd.\nI'm so sorry you and Macron, etc., have to provide nursing care Biden\nThis is REALLY not in your job description.   https://twitter.com/jeannieCsylvia/status/1801321015319896315  1718303371    []           False               NaN              NaN  1801321015319896315   en                                                                               @BidenHQ Thank you, PM Meloni, for shepherding our "lost little POTUS" back to the herd.\nI'm so sorry you and Macron, etc., have to provide nursing care Biden\nThis is REALLY not in your job description.           0             0      0.000       0.000 1801292720880947200.000 1801292720880947200.000       []                                                                                                                                                []    []  {'count': '11', 'state': 'EnabledWithCount'}        False                KamalaHQ    1801292720880947200.000           3315264553.000       NaN              NaN                                                                                                      {'id': 1595045671324844033, 'id_str': '1595045671324844033', 'url': 'https://twitter.com/Jeannie Sylvia', 'username': 'Jeannie Sylvia', 'rawDescription': '', 'created': datetime.datetime(2022, 11, 22, 13, 25, 16, tzinfo=datetime.timezone.utc), 'followersCount': 216, 'friendsCount': 366, 'statusesCount': 4166, 'favouritesCount': 9818, 'listedCount': 0, 'mediaCount': 161, 'location': 'Norfolk, VA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1595046462441885698/HyNmRZq9_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}   NaN    NaN
# 1  1801321014204178511                                                                                                                                                                                                                                                                         @MuskUniverseUsa 9  https://twitter.com/ConservativeRTJ/status/1801321014204178511  1718303371    []           False               NaN              NaN  1801321014204178511  und                                                                                                                                                                                                                                                                         @MuskUniverseUsa 9           0             0      0.000       0.000 1801251821203403264.000 1801251821203403264.000       []                           [{'id_str': '1711997156310355968', 'name': 'Elon Musk (Parody)', 'screen_name': 'MuskUniverseUsa', 'indices': [0, 16]}]    []   {'count': '2', 'state': 'EnabledWithCount'}        False         MuskUniverseUsa    1801251821203403264.000  1711997156310355968.000       NaN              NaN                                                                                                               {'id': 1524051593498435587, 'id_str': '1524051593498435587', 'url': 'https://twitter.com/Booker RT J', 'username': 'Booker RT J', 'rawDescription': '', 'created': datetime.datetime(2022, 5, 10, 15, 40, 47, tzinfo=datetime.timezone.utc), 'followersCount': 101, 'friendsCount': 131, 'statusesCount': 55, 'favouritesCount': 2093, 'listedCount': 0, 'mediaCount': 0, 'location': 'Illinois, USA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1526979312112619520/7_G8vEhf_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}   NaN    NaN
# 2  1801321014040686814                       @BidenHQ Lmfao. Biden has fallen down 17 times this year. You’re finding the one video where it was raining and he was wearing dress shoes down a metal ramp 😂😂😂 you guy have nothing on him.  \nGo find the cheer he got from those young cadets.  It was deafening  https://twitter.com/CostaGlaropoulo/status/1801321014040686814  1718303371    []           False               NaN              NaN  1801321014040686814   en                       @BidenHQ Lmfao. Biden has fallen down 17 times this year. You’re finding the one video where it was raining and he was wearing dress shoes down a metal ramp 😂😂😂 you guy have nothing on him.  \nGo find the cheer he got from those young cadets.  It was deafening           0             0      0.000       0.000 1801292720880947200.000 1801292720880947200.000       []                                                                                                                                                []    []  {'count': '26', 'state': 'EnabledWithCount'}        False                KamalaHQ    1801292720880947200.000           3315264553.000       NaN              NaN  {'id': 1518708043902562304, 'id_str': '1518708043902562304', 'url': 'https://twitter.com/Costa G', 'username': 'Costa G', 'rawDescription': 'I am a Son, a Husband, a Dad, a business owner and a Lover of The USA. 🇺🇸 Bring it Back from these Liberals', 'created': datetime.datetime(2022, 4, 25, 21, 46, 53, tzinfo=datetime.timezone.utc), 'followersCount': 1770, 'friendsCount': 1433, 'statusesCount': 27648, 'favouritesCount': 8663, 'listedCount': 29, 'mediaCount': 14458, 'location': 'Mansfield, MA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1809757878393401346/PjpQBI1__normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}   NaN    NaN
# 3  1801321012941729889  @TrumpDailyPosts Just remember to be EXTRA CAREFUL, Mr. President:\n\nJulius Caesar was attacked by political allies, some of whom FEIGNED "friendship" and "undying support"!\n\nIf Washington DC has taught you ANYTHING, it's that you CANNOT TRUST ANYBODY, there!\n\nMAGA  🇺🇸  💪  ♥️     https://twitter.com/PaulaDuvall2/status/1801321012941729889  1718303371    []           False               NaN              NaN  1801321012941729889   en  @TrumpDailyPosts Just remember to be EXTRA CAREFUL, Mr. President:\n\nJulius Caesar was attacked by political allies, some of whom FEIGNED "friendship" and "undying support"!\n\nIf Washington DC has taught you ANYTHING, it's that you CANNOT TRUST ANYBODY, there!\n\nMAGA  🇺🇸  💪  ♥️           0             0      1.000       0.000 1801317286382551040.000 1801317286382551040.000       []  [{'id_str': '1686901686185721857', 'name': 'Donald J. Trump Posts From His Truth Social', 'screen_name': 'TrumpDailyPosts', 'indices': [0, 16]}]    []  {'count': '79', 'state': 'EnabledWithCount'}        False         TrumpDailyPosts    1801317286382551040.000  1686901686185722112.000       NaN              NaN                                                                                                                             {'id': 896400632, 'id_str': '896400632', 'url': 'https://twitter.com/Paula Duvall', 'username': 'Paula Duvall', 'rawDescription': "No DM's.", 'created': datetime.datetime(2012, 10, 22, 0, 7, 59, tzinfo=datetime.timezone.utc), 'followersCount': 8548, 'friendsCount': 7119, 'statusesCount': 272598, 'favouritesCount': 40244, 'listedCount': 97, 'mediaCount': 350, 'location': '', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1693759202437861376/9D6MhVff_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}   NaN    NaN
# 4  1801321012736221676                                                                                                                                                                                                    @gem_insider Maybe I go for the two lowest caps\nGROK &amp; MAGA\n\nFor what it's worth      https://twitter.com/Exploits_99/status/1801321012736221676  1718303371    []           False               NaN              NaN  1801321012736221676   en                                                                                                                                                                                                    @gem_insider Maybe I go for the two lowest caps\nGROK &amp; MAGA\n\nFor what it's worth           0             0      0.000       0.000 1801313591859286528.000 1801313591859286528.000       []                                    [{'id_str': '1120219427277025280', 'name': '💎GEM INSIDER💎', 'screen_name': 'gem_insider', 'indices': [0, 12]}]    []  {'count': '40', 'state': 'EnabledWithCount'}        False             gem_insider    1801313591859286528.000  1120219427277025152.000       NaN              NaN                                                                   {'id': 802657177, 'id_str': '802657177', 'url': 'https://twitter.com/Whina', 'username': 'Whina', 'rawDescription': 'Designer @chainpeak\nAmbassador @ThreadFiOrg\nGem Hunter | Alpha Caller | 100x 🚀', 'created': datetime.datetime(2012, 9, 4, 15, 37, 19, tzinfo=datetime.timezone.utc), 'followersCount': 449, 'friendsCount': 702, 'statusesCount': 4831, 'favouritesCount': 5163, 'listedCount': 3, 'mediaCount': 393, 'location': 'Remote', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1829211544497848320/05Ahm9rx_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}   NaN    NaN

# %% [markdown]
# ## Raw Chunk Analysis to ensure consistency of column names

# %%
def analyze_partition_consistency():
    """
    Analyze column consistency across all CSV.GZ files in part_x folders.
    Reports column name mismatches and ordering differences.
    """
    import pandas as pd
    import glob
    import os
    from tabulate import tabulate
    from collections import defaultdict

    base_path = "/Volumes/T7/tweets_data/usc-x-24-us-election"
    
    # Store column information for each file
    file_columns = {}
    all_columns = set()
    
    # Find all part folders
    part_folders = glob.glob(os.path.join(base_path, "part_*"))
    
    print("🔍 Scanning partitions...")
    
    # Collect column information from each file
    for folder in sorted(part_folders):
        files = glob.glob(os.path.join(folder, "*.csv.gz"))
        for file_path in files:
            try:
                # Read just the header
                df = pd.read_csv(file_path, compression='gzip', nrows=0)
                file_columns[file_path] = list(df.columns)
                all_columns.update(df.columns)
                print(f"✓ Processed: {os.path.basename(file_path)}")
            except Exception as e:
                print(f"❌ Error processing {file_path}: {str(e)}")
    
    # Analysis results
    print("\n📊 Column Consistency Analysis")
    print("=" * 80)
    
    # 1. Column Presence Matrix
    presence_data = []
    for file_path, columns in file_columns.items():
        row = {
            'File': os.path.basename(file_path),
            **{col: '✓' if col in columns else '❌' for col in sorted(all_columns)}
        }
        presence_data.append(row)
    
    print("\n🔍 Column Presence Matrix:")
    print(tabulate(presence_data, headers='keys', tablefmt='pretty', showindex=False))
    
    # 2. Column Order Analysis
    print("\n📋 Column Order Variations:")
    unique_orders = defaultdict(list)
    for file_path, columns in file_columns.items():
        order_key = tuple(columns)
        unique_orders[order_key].append(os.path.basename(file_path))
    
    for idx, (order, files) in enumerate(unique_orders.items(), 1):
        print(f"\nVariation {idx}:")
        print("Files:", ", ".join(files))
        print("Column Order:")
        for i, col in enumerate(order, 1):
            print(f"{i:2d}. {col}")
    
    # 3. Summary Statistics
    print("\n📈 Summary Statistics:")
    print(f"Total files analyzed: {len(file_columns)}")
    print(f"Total unique columns found: {len(all_columns)}")
    print(f"Number of different column orders: {len(unique_orders)}")
    
    # 4. Missing Columns Report
    print("\n❌ Missing Columns Report:")
    reference_columns = set(next(iter(file_columns.values())))
    for file_path, columns in file_columns.items():
        missing = reference_columns - set(columns)
        extra = set(columns) - reference_columns
        if missing or extra:
            print(f"\nFile: {os.path.basename(file_path)}")
            if missing:
                print("Missing:", ", ".join(missing))
            if extra:
                print("Extra:", ", ".join(extra))

# Run the analysis
analyze_partition_consistency()
# Out:
# 🔍 Scanning partitions...
# ✓ Processed: may_july_chunk_1.csv.gz
# ✓ Processed: may_july_chunk_10.csv.gz
# ✓ Processed: may_july_chunk_11.csv.gz
# ✓ Processed: may_july_chunk_12.csv.gz
# ✓ Processed: may_july_chunk_13.csv.gz
# ✓ Processed: may_july_chunk_14.csv.gz
# ✓ Processed: may_july_chunk_15.csv.gz
# ✓ Processed: may_july_chunk_16.csv.gz
# ✓ Processed: may_july_chunk_17.csv.gz
# ✓ Processed: may_july_chunk_18.csv.gz
# ✓ Processed: may_july_chunk_19.csv.gz
# ✓ Processed: may_july_chunk_2.csv.gz
# ✓ Processed: may_july_chunk_20.csv.gz
# ✓ Processed: may_july_chunk_3.csv.gz
# ✓ Processed: may_july_chunk_4.csv.gz
# ✓ Processed: may_july_chunk_5.csv.gz
# ✓ Processed: may_july_chunk_6.csv.gz
# ✓ Processed: may_july_chunk_7.csv.gz
# ✓ Processed: may_july_chunk_8.csv.gz
# ✓ Processed: may_july_chunk_9.csv.gz
# ✓ Processed: may_july_chunk_181.csv.gz
# ✓ Processed: may_july_chunk_182.csv.gz
# ✓ Processed: may_july_chunk_183.csv.gz
# ✓ Processed: may_july_chunk_184.csv.gz
# ✓ Processed: may_july_chunk_185.csv.gz
# ✓ Processed: may_july_chunk_186.csv.gz
# ✓ Processed: may_july_chunk_187.csv.gz
# ✓ Processed: may_july_chunk_188.csv.gz
# ✓ Processed: may_july_chunk_189.csv.gz
# ✓ Processed: may_july_chunk_190.csv.gz
# ✓ Processed: may_july_chunk_191.csv.gz
# ✓ Processed: may_july_chunk_192.csv.gz
# ✓ Processed: may_july_chunk_193.csv.gz
# ✓ Processed: may_july_chunk_194.csv.gz
# ✓ Processed: may_july_chunk_195.csv.gz
# ✓ Processed: may_july_chunk_196.csv.gz
# ✓ Processed: may_july_chunk_197.csv.gz
# ✓ Processed: may_july_chunk_198.csv.gz
# ✓ Processed: may_july_chunk_199.csv.gz
# ✓ Processed: may_july_chunk_200.csv.gz
# ✓ Processed: may_july_chunk_201.csv.gz
# ✓ Processed: may_july_chunk_202.csv.gz
# ✓ Processed: may_july_chunk_203.csv.gz
# ✓ Processed: may_july_chunk_204.csv.gz
# ✓ Processed: may_july_chunk_205.csv.gz
# ✓ Processed: may_july_chunk_206.csv.gz
# ✓ Processed: may_july_chunk_207.csv.gz
# ✓ Processed: may_july_chunk_208.csv.gz
# ✓ Processed: may_july_chunk_209.csv.gz
# ✓ Processed: may_july_chunk_210.csv.gz
# ✓ Processed: may_july_chunk_211.csv.gz
# ✓ Processed: may_july_chunk_212.csv.gz
# ✓ Processed: may_july_chunk_213.csv.gz
# ✓ Processed: may_july_chunk_214.csv.gz
# ✓ Processed: may_july_chunk_215.csv.gz
# ✓ Processed: may_july_chunk_216.csv.gz
# ✓ Processed: may_july_chunk_217.csv.gz
# ✓ Processed: may_july_chunk_218.csv.gz
# ✓ Processed: may_july_chunk_219.csv.gz
# ✓ Processed: may_july_chunk_220.csv.gz
# ✓ Processed: may_july_chunk_221.csv.gz
# ✓ Processed: may_july_chunk_222.csv.gz
# ✓ Processed: may_july_chunk_223.csv.gz
# ✓ Processed: may_july_chunk_224.csv.gz
# ✓ Processed: may_july_chunk_225.csv.gz
# ✓ Processed: may_july_chunk_226.csv.gz
# ✓ Processed: may_july_chunk_227.csv.gz
# ✓ Processed: may_july_chunk_228.csv.gz
# ✓ Processed: may_july_chunk_229.csv.gz
# ✓ Processed: may_july_chunk_230.csv.gz
# ✓ Processed: may_july_chunk_231.csv.gz
# ✓ Processed: may_july_chunk_232.csv.gz
# ✓ Processed: may_july_chunk_233.csv.gz
# ✓ Processed: may_july_chunk_234.csv.gz
# ✓ Processed: may_july_chunk_235.csv.gz
# ✓ Processed: may_july_chunk_236.csv.gz
# ✓ Processed: may_july_chunk_237.csv.gz
# ✓ Processed: may_july_chunk_238.csv.gz
# ✓ Processed: may_july_chunk_239.csv.gz
# ✓ Processed: may_july_chunk_240.csv.gz
# ✓ Processed: may_july_chunk_241.csv.gz
# ✓ Processed: may_july_chunk_242.csv.gz
# ✓ Processed: may_july_chunk_243.csv.gz
# ✓ Processed: may_july_chunk_244.csv.gz
# ✓ Processed: may_july_chunk_245.csv.gz
# ✓ Processed: may_july_chunk_246.csv.gz
# ✓ Processed: may_july_chunk_247.csv.gz
# ✓ Processed: may_july_chunk_248.csv.gz
# ✓ Processed: may_july_chunk_249.csv.gz
# ✓ Processed: may_july_chunk_250.csv.gz
# ✓ Processed: may_july_chunk_251.csv.gz
# ✓ Processed: may_july_chunk_252.csv.gz
# ✓ Processed: may_july_chunk_253.csv.gz
# ✓ Processed: may_july_chunk_254.csv.gz
# ✓ Processed: may_july_chunk_255.csv.gz
# ✓ Processed: may_july_chunk_256.csv.gz
# ✓ Processed: may_july_chunk_257.csv.gz
# ✓ Processed: may_july_chunk_258.csv.gz
# ✓ Processed: may_july_chunk_259.csv.gz
# ✓ Processed: may_july_chunk_260.csv.gz
# ✓ Processed: may_july_chunk_261.csv.gz
# ✓ Processed: may_july_chunk_262.csv.gz
# ✓ Processed: may_july_chunk_263.csv.gz
# ✓ Processed: may_july_chunk_264.csv.gz
# ✓ Processed: may_july_chunk_265.csv.gz
# ✓ Processed: may_july_chunk_266.csv.gz
# ✓ Processed: may_july_chunk_267.csv.gz
# ✓ Processed: may_july_chunk_268.csv.gz
# ✓ Processed: may_july_chunk_269.csv.gz
# ✓ Processed: may_july_chunk_270.csv.gz
# ✓ Processed: may_july_chunk_271.csv.gz
# ✓ Processed: may_july_chunk_272.csv.gz
# ✓ Processed: may_july_chunk_273.csv.gz
# ✓ Processed: may_july_chunk_274.csv.gz
# ✓ Processed: may_july_chunk_275.csv.gz
# ✓ Processed: may_july_chunk_276.csv.gz
# ✓ Processed: may_july_chunk_277.csv.gz
# ✓ Processed: may_july_chunk_278.csv.gz
# ✓ Processed: may_july_chunk_279.csv.gz
# ✓ Processed: may_july_chunk_280.csv.gz
# ✓ Processed: may_july_chunk_281.csv.gz
# ✓ Processed: may_july_chunk_282.csv.gz
# ✓ Processed: may_july_chunk_283.csv.gz
# ✓ Processed: may_july_chunk_284.csv.gz
# ✓ Processed: may_july_chunk_285.csv.gz
# ✓ Processed: may_july_chunk_286.csv.gz
# ✓ Processed: may_july_chunk_287.csv.gz
# ✓ Processed: may_july_chunk_288.csv.gz
# ✓ Processed: may_july_chunk_289.csv.gz
# ✓ Processed: may_july_chunk_290.csv.gz
# ✓ Processed: may_july_chunk_291.csv.gz
# ✓ Processed: may_july_chunk_292.csv.gz
# ✓ Processed: may_july_chunk_293.csv.gz
# ✓ Processed: may_july_chunk_294.csv.gz
# ✓ Processed: may_july_chunk_295.csv.gz
# ✓ Processed: may_july_chunk_296.csv.gz
# ✓ Processed: may_july_chunk_297.csv.gz
# ✓ Processed: may_july_chunk_298.csv.gz
# ✓ Processed: may_july_chunk_299.csv.gz
# ✓ Processed: may_july_chunk_300.csv.gz
# ✓ Processed: may_july_chunk_301.csv.gz
# ✓ Processed: may_july_chunk_302.csv.gz
# ✓ Processed: may_july_chunk_303.csv.gz
# ✓ Processed: may_july_chunk_304.csv.gz
# ✓ Processed: may_july_chunk_305.csv.gz
# ✓ Processed: may_july_chunk_306.csv.gz
# ✓ Processed: may_july_chunk_307.csv.gz
# ✓ Processed: may_july_chunk_308.csv.gz
# ✓ Processed: may_july_chunk_309.csv.gz
# ✓ Processed: may_july_chunk_310.csv.gz
# ✓ Processed: may_july_chunk_311.csv.gz
# ✓ Processed: may_july_chunk_312.csv.gz
# ✓ Processed: may_july_chunk_313.csv.gz
# ✓ Processed: may_july_chunk_314.csv.gz
# ✓ Processed: may_july_chunk_315.csv.gz
# ✓ Processed: may_july_chunk_316.csv.gz
# ✓ Processed: may_july_chunk_317.csv.gz
# ✓ Processed: may_july_chunk_318.csv.gz
# ✓ Processed: may_july_chunk_319.csv.gz
# ✓ Processed: may_july_chunk_320.csv.gz
# ✓ Processed: may_july_chunk_321.csv.gz
# ✓ Processed: may_july_chunk_322.csv.gz
# ✓ Processed: may_july_chunk_323.csv.gz
# ✓ Processed: may_july_chunk_324.csv.gz
# ✓ Processed: may_july_chunk_325.csv.gz
# ✓ Processed: may_july_chunk_326.csv.gz
# ✓ Processed: may_july_chunk_327.csv.gz
# ✓ Processed: may_july_chunk_328.csv.gz
# ✓ Processed: may_july_chunk_329.csv.gz
# ✓ Processed: may_july_chunk_330.csv.gz
# ✓ Processed: may_july_chunk_331.csv.gz
# ✓ Processed: may_july_chunk_332.csv.gz
# ✓ Processed: may_july_chunk_333.csv.gz
# ✓ Processed: may_july_chunk_334.csv.gz
# ✓ Processed: may_july_chunk_335.csv.gz
# ✓ Processed: may_july_chunk_336.csv.gz
# ✓ Processed: may_july_chunk_337.csv.gz
# ✓ Processed: may_july_chunk_338.csv.gz
# ✓ Processed: may_july_chunk_339.csv.gz
# ✓ Processed: may_july_chunk_340.csv.gz
# ✓ Processed: may_july_chunk_341.csv.gz
# ✓ Processed: may_july_chunk_342.csv.gz
# ✓ Processed: may_july_chunk_343.csv.gz
# ✓ Processed: may_july_chunk_344.csv.gz
# ✓ Processed: may_july_chunk_345.csv.gz
# ✓ Processed: may_july_chunk_346.csv.gz
# ✓ Processed: may_july_chunk_347.csv.gz
# ✓ Processed: may_july_chunk_348.csv.gz
# ✓ Processed: may_july_chunk_349.csv.gz
# ✓ Processed: may_july_chunk_350.csv.gz
# ✓ Processed: may_july_chunk_351.csv.gz
# ✓ Processed: may_july_chunk_352.csv.gz
# ✓ Processed: may_july_chunk_353.csv.gz
# ✓ Processed: may_july_chunk_354.csv.gz
# ✓ Processed: may_july_chunk_355.csv.gz
# ✓ Processed: may_july_chunk_356.csv.gz
# ✓ Processed: may_july_chunk_357.csv.gz
# ✓ Processed: may_july_chunk_358.csv.gz
# ✓ Processed: may_july_chunk_359.csv.gz
# ✓ Processed: may_july_chunk_360.csv.gz
# ✓ Processed: may_july_chunk_361.csv.gz
# ✓ Processed: may_july_chunk_362.csv.gz
# ✓ Processed: may_july_chunk_363.csv.gz
# ✓ Processed: may_july_chunk_364.csv.gz
# ✓ Processed: may_july_chunk_365.csv.gz
# ✓ Processed: may_july_chunk_366.csv.gz
# ✓ Processed: may_july_chunk_367.csv.gz
# ✓ Processed: may_july_chunk_368.csv.gz
# ✓ Processed: may_july_chunk_369.csv.gz
# ✓ Processed: may_july_chunk_370.csv.gz
# ✓ Processed: may_july_chunk_371.csv.gz
# ✓ Processed: may_july_chunk_372.csv.gz
# ✓ Processed: may_july_chunk_373.csv.gz
# ✓ Processed: may_july_chunk_374.csv.gz
# ✓ Processed: may_july_chunk_375.csv.gz
# ✓ Processed: may_july_chunk_376.csv.gz
# ✓ Processed: may_july_chunk_377.csv.gz
# ✓ Processed: may_july_chunk_378.csv.gz
# ✓ Processed: may_july_chunk_379.csv.gz
# ✓ Processed: may_july_chunk_380.csv.gz
# ✓ Processed: may_july_chunk_21.csv.gz
# ✓ Processed: may_july_chunk_22.csv.gz
# ✓ Processed: may_july_chunk_23.csv.gz
# ✓ Processed: may_july_chunk_24.csv.gz
# ✓ Processed: may_july_chunk_25.csv.gz
# ✓ Processed: may_july_chunk_26.csv.gz
# ✓ Processed: may_july_chunk_27.csv.gz
# ✓ Processed: may_july_chunk_28.csv.gz
# ✓ Processed: may_july_chunk_29.csv.gz
# ✓ Processed: may_july_chunk_30.csv.gz
# ✓ Processed: may_july_chunk_31.csv.gz
# ✓ Processed: may_july_chunk_32.csv.gz
# ✓ Processed: may_july_chunk_33.csv.gz
# ✓ Processed: may_july_chunk_34.csv.gz
# ✓ Processed: may_july_chunk_35.csv.gz
# ✓ Processed: may_july_chunk_36.csv.gz
# ✓ Processed: may_july_chunk_37.csv.gz
# ✓ Processed: may_july_chunk_38.csv.gz
# ✓ Processed: may_july_chunk_39.csv.gz
# ✓ Processed: may_july_chunk_40.csv.gz
# ✓ Processed: may_july_chunk_381.csv.gz
# ✓ Processed: may_july_chunk_382.csv.gz
# ✓ Processed: may_july_chunk_383.csv.gz
# ✓ Processed: may_july_chunk_384.csv.gz
# ✓ Processed: may_july_chunk_385.csv.gz
# ✓ Processed: may_july_chunk_386.csv.gz
# ✓ Processed: may_july_chunk_387.csv.gz
# ✓ Processed: may_july_chunk_388.csv.gz
# ✓ Processed: may_july_chunk_389.csv.gz
# ✓ Processed: may_july_chunk_390.csv.gz
# ✓ Processed: may_july_chunk_391.csv.gz
# ✓ Processed: may_july_chunk_392.csv.gz
# ✓ Processed: may_july_chunk_393.csv.gz
# ✓ Processed: may_july_chunk_394.csv.gz
# ✓ Processed: may_july_chunk_395.csv.gz
# ✓ Processed: may_july_chunk_396.csv.gz
# ✓ Processed: may_july_chunk_397.csv.gz
# ✓ Processed: may_july_chunk_398.csv.gz
# ✓ Processed: may_july_chunk_399.csv.gz
# ✓ Processed: may_july_chunk_400.csv.gz
# ✓ Processed: may_july_chunk_401.csv.gz
# ✓ Processed: may_july_chunk_402.csv.gz
# ✓ Processed: may_july_chunk_403.csv.gz
# ✓ Processed: may_july_chunk_404.csv.gz
# ✓ Processed: may_july_chunk_405.csv.gz
# ✓ Processed: may_july_chunk_406.csv.gz
# ✓ Processed: may_july_chunk_407.csv.gz
# ✓ Processed: may_july_chunk_408.csv.gz
# ✓ Processed: may_july_chunk_409.csv.gz
# ✓ Processed: may_july_chunk_410.csv.gz
# ✓ Processed: may_july_chunk_411.csv.gz
# ✓ Processed: may_july_chunk_412.csv.gz
# ✓ Processed: may_july_chunk_413.csv.gz
# ✓ Processed: may_july_chunk_414.csv.gz
# ✓ Processed: may_july_chunk_415.csv.gz
# ✓ Processed: may_july_chunk_416.csv.gz
# ✓ Processed: may_july_chunk_417.csv.gz
# ✓ Processed: may_july_chunk_418.csv.gz
# ✓ Processed: may_july_chunk_419.csv.gz
# ✓ Processed: may_july_chunk_420.csv.gz
# ✓ Processed: may_july_chunk_421.csv.gz
# ✓ Processed: may_july_chunk_422.csv.gz
# ✓ Processed: may_july_chunk_423.csv.gz
# ✓ Processed: may_july_chunk_424.csv.gz
# ✓ Processed: may_july_chunk_425.csv.gz
# ✓ Processed: may_july_chunk_426.csv.gz
# ✓ Processed: may_july_chunk_427.csv.gz
# ✓ Processed: may_july_chunk_428.csv.gz
# ✓ Processed: may_july_chunk_429.csv.gz
# ✓ Processed: may_july_chunk_430.csv.gz
# ✓ Processed: may_july_chunk_431.csv.gz
# ✓ Processed: may_july_chunk_432.csv.gz
# ✓ Processed: may_july_chunk_433.csv.gz
# ✓ Processed: may_july_chunk_434.csv.gz
# ✓ Processed: may_july_chunk_435.csv.gz
# ✓ Processed: may_july_chunk_436.csv.gz
# ✓ Processed: may_july_chunk_437.csv.gz
# ✓ Processed: may_july_chunk_438.csv.gz
# ✓ Processed: may_july_chunk_439.csv.gz
# ✓ Processed: may_july_chunk_440.csv.gz
# ✓ Processed: aug_chunk_1.csv.gz
# ✓ Processed: aug_chunk_10.csv.gz
# ✓ Processed: aug_chunk_11.csv.gz
# ✓ Processed: aug_chunk_12.csv.gz
# ✓ Processed: aug_chunk_13.csv.gz
# ✓ Processed: aug_chunk_14.csv.gz
# ✓ Processed: aug_chunk_15.csv.gz
# ✓ Processed: aug_chunk_16.csv.gz
# ✓ Processed: aug_chunk_17.csv.gz
# ✓ Processed: aug_chunk_18.csv.gz
# ✓ Processed: aug_chunk_19.csv.gz
# ✓ Processed: aug_chunk_2.csv.gz
# ✓ Processed: aug_chunk_20.csv.gz
# ✓ Processed: aug_chunk_3.csv.gz
# ✓ Processed: aug_chunk_4.csv.gz
# ✓ Processed: aug_chunk_5.csv.gz
# ✓ Processed: aug_chunk_6.csv.gz
# ✓ Processed: aug_chunk_7.csv.gz
# ✓ Processed: aug_chunk_8.csv.gz
# ✓ Processed: aug_chunk_9.csv.gz
# ✓ Processed: aug_chunk_21.csv.gz
# ✓ Processed: aug_chunk_22.csv.gz
# ✓ Processed: aug_chunk_23.csv.gz
# ✓ Processed: aug_chunk_24.csv.gz
# ✓ Processed: aug_chunk_25.csv.gz
# ✓ Processed: aug_chunk_26.csv.gz
# ✓ Processed: aug_chunk_27.csv.gz
# ✓ Processed: aug_chunk_28.csv.gz
# ✓ Processed: aug_chunk_29.csv.gz
# ✓ Processed: aug_chunk_30.csv.gz
# ✓ Processed: aug_chunk_31.csv.gz
# ✓ Processed: aug_chunk_32.csv.gz
# ✓ Processed: aug_chunk_33.csv.gz
# ✓ Processed: aug_chunk_34.csv.gz
# ✓ Processed: aug_chunk_35.csv.gz
# ✓ Processed: aug_chunk_36.csv.gz
# ✓ Processed: aug_chunk_37.csv.gz
# ✓ Processed: aug_chunk_38.csv.gz
# ✓ Processed: aug_chunk_39.csv.gz
# ✓ Processed: aug_chunk_40.csv.gz
# ✓ Processed: aug_chunk_41.csv.gz
# ✓ Processed: aug_chunk_42.csv.gz
# ✓ Processed: aug_chunk_43.csv.gz
# ✓ Processed: aug_chunk_44.csv.gz
# ✓ Processed: aug_chunk_45.csv.gz
# ✓ Processed: aug_chunk_46.csv.gz
# ✓ Processed: aug_chunk_47.csv.gz
# ✓ Processed: aug_chunk_48.csv.gz
# ✓ Processed: aug_chunk_49.csv.gz
# ✓ Processed: aug_chunk_50.csv.gz
# ✓ Processed: aug_chunk_51.csv.gz
# ✓ Processed: aug_chunk_52.csv.gz
# ✓ Processed: aug_chunk_53.csv.gz
# ✓ Processed: aug_chunk_54.csv.gz
# ✓ Processed: aug_chunk_55.csv.gz
# ✓ Processed: aug_chunk_56.csv.gz
# ✓ Processed: aug_chunk_57.csv.gz
# ✓ Processed: aug_chunk_58.csv.gz
# ✓ Processed: aug_chunk_59.csv.gz
# ✓ Processed: aug_chunk_60.csv.gz
# ✓ Processed: aug_chunk_61.csv.gz
# ✓ Processed: aug_chunk_62.csv.gz
# ✓ Processed: aug_chunk_63.csv.gz
# ✓ Processed: aug_chunk_64.csv.gz
# ✓ Processed: aug_chunk_65.csv.gz
# ✓ Processed: aug_chunk_66.csv.gz
# ✓ Processed: aug_chunk_67.csv.gz
# ✓ Processed: aug_chunk_68.csv.gz
# ✓ Processed: aug_chunk_69.csv.gz
# ✓ Processed: aug_chunk_70.csv.gz
# ✓ Processed: aug_chunk_71.csv.gz
# ✓ Processed: aug_chunk_72.csv.gz
# ✓ Processed: aug_chunk_73.csv.gz
# ✓ Processed: aug_chunk_74.csv.gz
# ✓ Processed: aug_chunk_75.csv.gz
# ✓ Processed: aug_chunk_76.csv.gz
# ✓ Processed: aug_chunk_77.csv.gz
# ✓ Processed: aug_chunk_78.csv.gz
# ✓ Processed: aug_chunk_79.csv.gz
# ✓ Processed: aug_chunk_80.csv.gz
# ✓ Processed: aug_chunk_100.csv.gz
# ✓ Processed: aug_chunk_81.csv.gz
# ✓ Processed: aug_chunk_82.csv.gz
# ✓ Processed: aug_chunk_83.csv.gz
# ✓ Processed: aug_chunk_84.csv.gz
# ✓ Processed: aug_chunk_85.csv.gz
# ✓ Processed: aug_chunk_86.csv.gz
# ✓ Processed: aug_chunk_87.csv.gz
# ✓ Processed: aug_chunk_88.csv.gz
# ✓ Processed: aug_chunk_89.csv.gz
# ✓ Processed: aug_chunk_90.csv.gz
# ✓ Processed: aug_chunk_91.csv.gz
# ✓ Processed: aug_chunk_92.csv.gz
# ✓ Processed: aug_chunk_93.csv.gz
# ✓ Processed: aug_chunk_94.csv.gz
# ✓ Processed: aug_chunk_95.csv.gz
# ✓ Processed: aug_chunk_96.csv.gz
# ✓ Processed: aug_chunk_97.csv.gz
# ✓ Processed: aug_chunk_98.csv.gz
# ✓ Processed: aug_chunk_99.csv.gz
# ✓ Processed: aug_chunk_101.csv.gz
# ✓ Processed: aug_chunk_102.csv.gz
# ✓ Processed: aug_chunk_103.csv.gz
# ✓ Processed: aug_chunk_104.csv.gz
# ✓ Processed: aug_chunk_105.csv.gz
# ✓ Processed: aug_chunk_106.csv.gz
# ✓ Processed: aug_chunk_107.csv.gz
# ✓ Processed: aug_chunk_108.csv.gz
# ✓ Processed: aug_chunk_109.csv.gz
# ✓ Processed: aug_chunk_110.csv.gz
# ✓ Processed: aug_chunk_111.csv.gz
# ✓ Processed: aug_chunk_112.csv.gz
# ✓ Processed: aug_chunk_113.csv.gz
# ✓ Processed: aug_chunk_114.csv.gz
# ✓ Processed: aug_chunk_115.csv.gz
# ✓ Processed: aug_chunk_116.csv.gz
# ✓ Processed: aug_chunk_117.csv.gz
# ✓ Processed: september_chunk_1.csv.gz
# ✓ Processed: september_chunk_10.csv.gz
# ✓ Processed: september_chunk_11.csv.gz
# ✓ Processed: september_chunk_12.csv.gz
# ✓ Processed: september_chunk_13.csv.gz
# ✓ Processed: september_chunk_14.csv.gz
# ✓ Processed: september_chunk_15.csv.gz
# ✓ Processed: september_chunk_16.csv.gz
# ✓ Processed: september_chunk_17.csv.gz
# ✓ Processed: september_chunk_18.csv.gz
# ✓ Processed: september_chunk_19.csv.gz
# ✓ Processed: september_chunk_2.csv.gz
# ✓ Processed: september_chunk_20.csv.gz
# ✓ Processed: september_chunk_3.csv.gz
# ✓ Processed: september_chunk_4.csv.gz
# ✓ Processed: september_chunk_5.csv.gz
# ✓ Processed: september_chunk_6.csv.gz
# ✓ Processed: september_chunk_7.csv.gz
# ✓ Processed: september_chunk_8.csv.gz
# ✓ Processed: september_chunk_9.csv.gz
# ✓ Processed: may_july_chunk_41.csv.gz
# ✓ Processed: may_july_chunk_42.csv.gz
# ✓ Processed: may_july_chunk_43.csv.gz
# ✓ Processed: may_july_chunk_44.csv.gz
# ✓ Processed: may_july_chunk_45.csv.gz
# ✓ Processed: may_july_chunk_46.csv.gz
# ✓ Processed: may_july_chunk_47.csv.gz
# ✓ Processed: may_july_chunk_48.csv.gz
# ✓ Processed: may_july_chunk_49.csv.gz
# ✓ Processed: may_july_chunk_50.csv.gz
# ✓ Processed: may_july_chunk_51.csv.gz
# ✓ Processed: may_july_chunk_52.csv.gz
# ✓ Processed: may_july_chunk_53.csv.gz
# ✓ Processed: may_july_chunk_54.csv.gz
# ✓ Processed: may_july_chunk_55.csv.gz
# ✓ Processed: may_july_chunk_56.csv.gz
# ✓ Processed: may_july_chunk_57.csv.gz
# ✓ Processed: may_july_chunk_58.csv.gz
# ✓ Processed: may_july_chunk_59.csv.gz
# ✓ Processed: may_july_chunk_60.csv.gz
# ✓ Processed: september_chunk_21.csv.gz
# ✓ Processed: september_chunk_22.csv.gz
# ✓ Processed: september_chunk_23.csv.gz
# ✓ Processed: september_chunk_24.csv.gz
# ✓ Processed: september_chunk_25.csv.gz
# ✓ Processed: september_chunk_26.csv.gz
# ✓ Processed: september_chunk_27.csv.gz
# ✓ Processed: september_chunk_28.csv.gz
# ✓ Processed: september_chunk_29.csv.gz
# ✓ Processed: september_chunk_30.csv.gz
# ✓ Processed: september_chunk_31.csv.gz
# ✓ Processed: september_chunk_32.csv.gz
# ✓ Processed: september_chunk_33.csv.gz
# ✓ Processed: september_chunk_34.csv.gz
# ✓ Processed: september_chunk_35.csv.gz
# ✓ Processed: september_chunk_36.csv.gz
# ✓ Processed: september_chunk_37.csv.gz
# ✓ Processed: september_chunk_38.csv.gz
# ✓ Processed: september_chunk_39.csv.gz
# ✓ Processed: september_chunk_40.csv.gz
# ✓ Processed: september_chunk_41.csv.gz
# ✓ Processed: september_chunk_42.csv.gz
# ✓ Processed: september_chunk_43.csv.gz
# ✓ Processed: september_chunk_44.csv.gz
# ✓ Processed: september_chunk_45.csv.gz
# ✓ Processed: september_chunk_46.csv.gz
# ✓ Processed: september_chunk_47.csv.gz
# ✓ Processed: september_chunk_48.csv.gz
# ✓ Processed: september_chunk_49.csv.gz
# ✓ Processed: september_chunk_50.csv.gz
# ✓ Processed: september_chunk_51.csv.gz
# ✓ Processed: september_chunk_52.csv.gz
# ✓ Processed: september_chunk_53.csv.gz
# ✓ Processed: september_chunk_54.csv.gz
# ✓ Processed: september_chunk_55.csv.gz
# ✓ Processed: september_chunk_56.csv.gz
# ✓ Processed: september_chunk_57.csv.gz
# ✓ Processed: september_chunk_58.csv.gz
# ✓ Processed: september_chunk_59.csv.gz
# ✓ Processed: september_chunk_60.csv.gz
# ✓ Processed: september_chunk_61.csv.gz
# ✓ Processed: september_chunk_62.csv.gz
# ✓ Processed: september_chunk_63.csv.gz
# ✓ Processed: september_chunk_64.csv.gz
# ✓ Processed: september_chunk_65.csv.gz
# ✓ Processed: september_chunk_66.csv.gz
# ✓ Processed: september_chunk_67.csv.gz
# ✓ Processed: september_chunk_68.csv.gz
# ✓ Processed: september_chunk_69.csv.gz
# ✓ Processed: september_chunk_70.csv.gz
# ✓ Processed: september_chunk_71.csv.gz
# ✓ Processed: september_chunk_72.csv.gz
# ✓ Processed: september_chunk_73.csv.gz
# ✓ Processed: september_chunk_74.csv.gz
# ✓ Processed: september_chunk_75.csv.gz
# ✓ Processed: september_chunk_76.csv.gz
# ✓ Processed: september_chunk_77.csv.gz
# ✓ Processed: september_chunk_78.csv.gz
# ✓ Processed: september_chunk_79.csv.gz
# ✓ Processed: september_chunk_80.csv.gz
# ✓ Processed: september_chunk_100.csv.gz
# ✓ Processed: september_chunk_81.csv.gz
# ✓ Processed: september_chunk_82.csv.gz
# ✓ Processed: september_chunk_83.csv.gz
# ✓ Processed: september_chunk_84.csv.gz
# ✓ Processed: september_chunk_85.csv.gz
# ✓ Processed: september_chunk_86.csv.gz
# ✓ Processed: september_chunk_87.csv.gz
# ✓ Processed: september_chunk_88.csv.gz
# ✓ Processed: september_chunk_89.csv.gz
# ✓ Processed: september_chunk_90.csv.gz
# ✓ Processed: september_chunk_91.csv.gz
# ✓ Processed: september_chunk_92.csv.gz
# ✓ Processed: september_chunk_93.csv.gz
# ✓ Processed: september_chunk_94.csv.gz
# ✓ Processed: september_chunk_95.csv.gz
# ✓ Processed: september_chunk_96.csv.gz
# ✓ Processed: september_chunk_97.csv.gz
# ✓ Processed: september_chunk_98.csv.gz
# ✓ Processed: september_chunk_99.csv.gz
# ✓ Processed: september_chunk_101.csv.gz
# ✓ Processed: september_chunk_102.csv.gz
# ✓ Processed: september_chunk_103.csv.gz
# ✓ Processed: september_chunk_104.csv.gz
# ✓ Processed: september_chunk_105.csv.gz
# ✓ Processed: september_chunk_106.csv.gz
# ✓ Processed: september_chunk_107.csv.gz
# ✓ Processed: september_chunk_108.csv.gz
# ✓ Processed: september_chunk_109.csv.gz
# ✓ Processed: september_chunk_110.csv.gz
# ✓ Processed: september_chunk_111.csv.gz
# ✓ Processed: september_chunk_112.csv.gz
# ✓ Processed: september_chunk_113.csv.gz
# ✓ Processed: september_chunk_114.csv.gz
# ✓ Processed: september_chunk_115.csv.gz
# ✓ Processed: september_chunk_116.csv.gz
# ✓ Processed: september_chunk_117.csv.gz
# ✓ Processed: september_chunk_118.csv.gz
# ✓ Processed: september_chunk_119.csv.gz
# ✓ Processed: september_chunk_120.csv.gz
# ✓ Processed: september_chunk_121.csv.gz
# ✓ Processed: september_chunk_122.csv.gz
# ✓ Processed: september_chunk_123.csv.gz
# ✓ Processed: september_chunk_124.csv.gz
# ✓ Processed: september_chunk_125.csv.gz
# ✓ Processed: september_chunk_126.csv.gz
# ✓ Processed: september_chunk_127.csv.gz
# ✓ Processed: september_chunk_128.csv.gz
# ✓ Processed: september_chunk_129.csv.gz
# ✓ Processed: september_chunk_130.csv.gz
# ✓ Processed: september_chunk_131.csv.gz
# ✓ Processed: september_chunk_132.csv.gz
# ✓ Processed: september_chunk_133.csv.gz
# ✓ Processed: september_chunk_134.csv.gz
# ✓ Processed: september_chunk_135.csv.gz
# ✓ Processed: september_chunk_136.csv.gz
# ✓ Processed: september_chunk_137.csv.gz
# ✓ Processed: september_chunk_138.csv.gz
# ✓ Processed: september_chunk_139.csv.gz
# ✓ Processed: september_chunk_140.csv.gz
# ✓ Processed: may_july_chunk_61.csv.gz
# ✓ Processed: may_july_chunk_62.csv.gz
# ✓ Processed: may_july_chunk_63.csv.gz
# ✓ Processed: may_july_chunk_64.csv.gz
# ✓ Processed: may_july_chunk_65.csv.gz
# ✓ Processed: may_july_chunk_66.csv.gz
# ✓ Processed: may_july_chunk_67.csv.gz
# ✓ Processed: may_july_chunk_68.csv.gz
# ✓ Processed: may_july_chunk_69.csv.gz
# ✓ Processed: may_july_chunk_70.csv.gz
# ✓ Processed: may_july_chunk_71.csv.gz
# ✓ Processed: may_july_chunk_72.csv.gz
# ✓ Processed: may_july_chunk_73.csv.gz
# ✓ Processed: may_july_chunk_74.csv.gz
# ✓ Processed: may_july_chunk_75.csv.gz
# ✓ Processed: may_july_chunk_76.csv.gz
# ✓ Processed: may_july_chunk_77.csv.gz
# ✓ Processed: may_july_chunk_78.csv.gz
# ✓ Processed: may_july_chunk_79.csv.gz
# ✓ Processed: may_july_chunk_80.csv.gz
# ✓ Processed: may_july_chunk_100.csv.gz
# ✓ Processed: may_july_chunk_81.csv.gz
# ✓ Processed: may_july_chunk_82.csv.gz
# ✓ Processed: may_july_chunk_83.csv.gz
# ✓ Processed: may_july_chunk_84.csv.gz
# ✓ Processed: may_july_chunk_85.csv.gz
# ✓ Processed: may_july_chunk_86.csv.gz
# ✓ Processed: may_july_chunk_87.csv.gz
# ✓ Processed: may_july_chunk_88.csv.gz
# ✓ Processed: may_july_chunk_89.csv.gz
# ✓ Processed: may_july_chunk_90.csv.gz
# ✓ Processed: may_july_chunk_91.csv.gz
# ✓ Processed: may_july_chunk_92.csv.gz
# ✓ Processed: may_july_chunk_93.csv.gz
# ✓ Processed: may_july_chunk_94.csv.gz
# ✓ Processed: may_july_chunk_95.csv.gz
# ✓ Processed: may_july_chunk_96.csv.gz
# ✓ Processed: may_july_chunk_97.csv.gz
# ✓ Processed: may_july_chunk_98.csv.gz
# ✓ Processed: may_july_chunk_99.csv.gz
# ✓ Processed: may_july_chunk_101.csv.gz
# ✓ Processed: may_july_chunk_102.csv.gz
# ✓ Processed: may_july_chunk_103.csv.gz
# ✓ Processed: may_july_chunk_104.csv.gz
# ✓ Processed: may_july_chunk_105.csv.gz
# ✓ Processed: may_july_chunk_106.csv.gz
# ✓ Processed: may_july_chunk_107.csv.gz
# ✓ Processed: may_july_chunk_108.csv.gz
# ✓ Processed: may_july_chunk_109.csv.gz
# ✓ Processed: may_july_chunk_110.csv.gz
# ✓ Processed: may_july_chunk_111.csv.gz
# ✓ Processed: may_july_chunk_112.csv.gz
# ✓ Processed: may_july_chunk_113.csv.gz
# ✓ Processed: may_july_chunk_114.csv.gz
# ✓ Processed: may_july_chunk_115.csv.gz
# ✓ Processed: may_july_chunk_116.csv.gz
# ✓ Processed: may_july_chunk_117.csv.gz
# ✓ Processed: may_july_chunk_118.csv.gz
# ✓ Processed: may_july_chunk_119.csv.gz
# ✓ Processed: may_july_chunk_120.csv.gz
# ✓ Processed: may_july_chunk_121.csv.gz
# ✓ Processed: may_july_chunk_122.csv.gz
# ✓ Processed: may_july_chunk_123.csv.gz
# ✓ Processed: may_july_chunk_124.csv.gz
# ✓ Processed: may_july_chunk_125.csv.gz
# ✓ Processed: may_july_chunk_126.csv.gz
# ✓ Processed: may_july_chunk_127.csv.gz
# ✓ Processed: may_july_chunk_128.csv.gz
# ✓ Processed: may_july_chunk_129.csv.gz
# ✓ Processed: may_july_chunk_130.csv.gz
# ✓ Processed: may_july_chunk_131.csv.gz
# ✓ Processed: may_july_chunk_132.csv.gz
# ✓ Processed: may_july_chunk_133.csv.gz
# ✓ Processed: may_july_chunk_134.csv.gz
# ✓ Processed: may_july_chunk_135.csv.gz
# ✓ Processed: may_july_chunk_136.csv.gz
# ✓ Processed: may_july_chunk_137.csv.gz
# ✓ Processed: may_july_chunk_138.csv.gz
# ✓ Processed: may_july_chunk_139.csv.gz
# ✓ Processed: may_july_chunk_140.csv.gz
# ✓ Processed: may_july_chunk_141.csv.gz
# ✓ Processed: may_july_chunk_142.csv.gz
# ✓ Processed: may_july_chunk_143.csv.gz
# ✓ Processed: may_july_chunk_144.csv.gz
# ✓ Processed: may_july_chunk_145.csv.gz
# ✓ Processed: may_july_chunk_146.csv.gz
# ✓ Processed: may_july_chunk_147.csv.gz
# ✓ Processed: may_july_chunk_148.csv.gz
# ✓ Processed: may_july_chunk_149.csv.gz
# ✓ Processed: may_july_chunk_150.csv.gz
# ✓ Processed: may_july_chunk_151.csv.gz
# ✓ Processed: may_july_chunk_152.csv.gz
# ✓ Processed: may_july_chunk_153.csv.gz
# ✓ Processed: may_july_chunk_154.csv.gz
# ✓ Processed: may_july_chunk_155.csv.gz
# ✓ Processed: may_july_chunk_156.csv.gz
# ✓ Processed: may_july_chunk_157.csv.gz
# ✓ Processed: may_july_chunk_158.csv.gz
# ✓ Processed: may_july_chunk_159.csv.gz
# ✓ Processed: may_july_chunk_160.csv.gz
# ✓ Processed: may_july_chunk_161.csv.gz
# ✓ Processed: may_july_chunk_162.csv.gz
# ✓ Processed: may_july_chunk_163.csv.gz
# ✓ Processed: may_july_chunk_164.csv.gz
# ✓ Processed: may_july_chunk_165.csv.gz
# ✓ Processed: may_july_chunk_166.csv.gz
# ✓ Processed: may_july_chunk_167.csv.gz
# ✓ Processed: may_july_chunk_168.csv.gz
# ✓ Processed: may_july_chunk_169.csv.gz
# ✓ Processed: may_july_chunk_170.csv.gz
# ✓ Processed: may_july_chunk_171.csv.gz
# ✓ Processed: may_july_chunk_172.csv.gz
# ✓ Processed: may_july_chunk_173.csv.gz
# ✓ Processed: may_july_chunk_174.csv.gz
# ✓ Processed: may_july_chunk_175.csv.gz
# ✓ Processed: may_july_chunk_176.csv.gz
# ✓ Processed: may_july_chunk_177.csv.gz
# ✓ Processed: may_july_chunk_178.csv.gz
# ✓ Processed: may_july_chunk_179.csv.gz
# ✓ Processed: may_july_chunk_180.csv.gz
#
# 📊 Column Consistency Analysis
# ================================================================================
#
# 🔍 Column Presence Matrix:
# +----------------------------+----+-------+-----------------+----------------+-------------------+------+-------+----------+----+--------+-------------------------+---------------------------+-------------------------+------+-----------+-------+----------+-------+----------------+------------+-------------+------------+------------+--------------+----------------+------------------+-----------------+------+------+-----+------+----------+-----------+
# |            File            | 0  | _type | cash_app_handle | conversationId | conversationIdStr | date | epoch | hashtags | id | id_str | in_reply_to_screen_name | in_reply_to_status_id_str | in_reply_to_user_id_str | lang | likeCount | links | location | media | mentionedUsers | quoteCount | quotedTweet | rawContent | replyCount | retweetCount | retweetedTweet | retweetedTweetID | retweetedUserID | text | type | url | user | username | viewCount |
# +----------------------------+----+-------+-----------------+----------------+-------------------+------+-------+----------+----+--------+-------------------------+---------------------------+-------------------------+------+-----------+-------+----------+-------+----------------+------------+-------------+------------+------------+--------------+----------------+------------------+-----------------+------+------+-----+------+----------+-----------+
# |  may_july_chunk_1.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_10.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_11.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_12.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_13.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_14.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_15.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_16.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_17.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_18.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_19.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_2.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_20.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_3.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_4.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_5.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_6.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_7.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_8.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# |  may_july_chunk_9.csv.gz   | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_181.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_182.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_183.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_184.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_185.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_186.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_187.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_188.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_189.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_190.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_191.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_192.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_193.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_194.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_195.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_196.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_197.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_198.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_199.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_200.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_201.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_202.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_203.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# | may_july_chunk_204.csv.gz  | ❌ |   ✓   |        ✓        |       ✓        |         ✓         |  ✓   |   ✓   |    ✓     | ✓  |   ✓    |            ✓            |             ✓             |            ✓            |  ✓   |     ✓     |   ✓   |    ✓     |   ✓   |       ✓        |     ✓      |      ✓      |     ✓      |     ✓      |      ✓       |       ✓        |        ✓         |        ✓        |  ✓   |  ❌  |  ✓  |  ✓   |    ❌    |     ✓     |
# ...
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_46.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_47.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_48.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_49.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_50.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_51.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_52.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_53.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_54.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_55.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_56.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_57.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_58.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_59.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_60.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_61.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_62.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_63.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_64.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_65.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_66.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_67.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_68.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_69.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_70.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_71.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_72.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_73.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_74.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_75.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_76.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_77.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_78.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_79.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_80.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_100.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_81.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_82.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_83.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_84.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_85.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_86.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_87.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_88.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_89.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_90.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_91.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_92.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_93.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_94.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_95.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_96.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_97.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_98.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_99.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_101.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_102.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_103.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_104.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_105.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_106.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_107.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_108.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_109.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_110.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_111.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_112.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_113.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_114.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_115.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_116.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: aug_chunk_117.csv.gz
# Missing: date, _type
# Extra: username, 0, type
#
# File: september_chunk_1.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_10.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_11.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_12.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_13.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_14.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_15.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_16.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_17.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_18.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_19.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_2.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_20.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_3.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_4.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_5.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_6.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_7.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_8.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_9.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_21.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_22.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_23.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_24.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_25.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_26.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_27.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_28.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_29.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_30.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_31.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_32.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_33.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_34.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_35.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_36.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_37.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_38.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_39.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_40.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_41.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_42.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_43.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_44.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_45.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_46.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_47.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_48.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_49.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_50.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_51.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_52.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_53.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_54.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_55.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_56.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_57.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_58.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_59.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_60.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_61.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_62.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_63.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_64.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_65.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_66.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_67.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_68.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_69.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_70.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_71.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_72.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_73.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_74.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_75.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_76.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_77.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_78.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_79.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_80.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_100.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_81.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_82.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_83.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_84.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_85.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_86.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_87.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_88.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_89.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_90.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_91.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_92.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_93.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_94.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_95.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_96.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_97.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_98.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_99.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_101.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_102.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_103.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_104.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_105.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_106.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_107.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_108.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_109.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_110.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_111.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_112.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_113.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_114.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_115.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_116.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_117.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_118.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_119.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_120.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_121.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_122.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_123.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_124.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_125.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_126.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_127.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_128.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_129.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_130.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_131.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_132.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_133.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_134.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_135.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_136.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_137.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_138.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_139.csv.gz
# Missing: date, _type
# Extra: username, type
#
# File: september_chunk_140.csv.gz
# Missing: date, _type
# Extra: username, type

# %% [markdown]
# ### Extract sample to a csv format for analysis

# %%
import os 

def sample_and_save_partition(output_path="sample_data/sampled_tweets_b.csv"):
    """
    Sample 1000 rows from a partition and save to CSV.
    
    Args:
        output_path (str): Path where the sampled CSV will be saved
    """
    # Get the sample
    df = sample_partition()
    
    # Create output directory if it doesn't exist
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    # Save to CSV
    df.to_csv(output_path, index=False)
    print(f"\nSaved {len(df)} rows to: {output_path}")
    
    return df

# Example usage:
if __name__ == "__main__":
    df = sample_and_save_partition()
# Out:
# Sampling from: sample_data/part_1/may_july_chunk_11.csv.gz
#
# Saved 50000 rows to: sample_data/sampled_tweets_b.csv

# %% [markdown]
# ### Analyze Sampled CSV file

# %%
def analyze_columns(df):
    """
    Analyze each column in the dataframe and provide detailed information about data types,
    sample values, and basic statistics.
    
    Args:
        df (pd.DataFrame): Input dataframe to analyze
        
    Returns:
        dict: Dictionary containing analysis results for each column
    """
    analysis = {}
    
    for column in df.columns:
        # Initialize column analysis
        col_data = {
            'dtype': str(df[column].dtype),
            'null_count': df[column].isna().sum(),
            'null_percentage': (df[column].isna().sum() / len(df)) * 100,
            'unique_count': df[column].nunique(),
            'sample_values': df[column].dropna().head(3).tolist()
        }
        
        # Add type-specific analysis
        if df[column].dtype in ['int64', 'float64']:
            col_data.update({
                'min': df[column].min(),
                'max': df[column].max(),
                'mean': df[column].mean(),
                'median': df[column].median()
            })
        elif df[column].dtype == 'object':
            # For string/object columns
            non_null_values = df[column].dropna()
            if len(non_null_values) > 0:
                col_data.update({
                    'avg_length': non_null_values.str.len().mean(),
                    'max_length': non_null_values.str.len().max(),
                    'contains_numbers': any(str(x).replace('.','',1).isdigit() 
                                         for x in non_null_values.head(100)),
                    'most_common': df[column].value_counts().head(3).to_dict()
                })
        
        analysis[column] = col_data
    
    return analysis

def print_column_analysis(df):
    """Print a formatted analysis of all columns in the dataframe."""
    analysis = analyze_columns(df)
    
    print("\n📊 Column Analysis Report")
    print("=" * 100)
    
    for column, data in analysis.items():
        print(f"\n📌 Column: {column}")
        print("─" * 80)
        
        # Basic Info
        print(f"📋 Basic Information:")
        print(f"   • Type: {data['dtype']}")
        print(f"   • Null Values: {data['null_count']} ({data['null_percentage']:.1f}%)")
        print(f"   • Unique Values: {data['unique_count']}")
        print(f"   • Sample Values: {', '.join(str(x) for x in data['sample_values'])}")
        
        # Numeric Statistics
        if 'mean' in data:
            print(f"\n📈 Numeric Statistics:")
            print(f"   • Min: {data['min']:,.2f}")
            print(f"   • Max: {data['max']:,.2f}")
            print(f"   • Mean: {data['mean']:,.2f}")
            print(f"   • Median: {data['median']:,.2f}")
        
        # String Statistics
        if 'avg_length' in data:
            print(f"\n📝 String Statistics:")
            print(f"   • Average Length: {data['avg_length']:.1f}")
            print(f"   • Max Length: {data['max_length']}")
            print(f"   • Contains Numbers: {'✓' if data['contains_numbers'] else '✗'}")
            print(f"   • Most Common Values:")
            for value, count in data['most_common'].items():
                print(f"     - {value}: {count:,} occurrences")

# Example usage:
if __name__ == "__main__":
    df = sample_partition()
    print_column_analysis(df)
# Out:
# Sampling from: sample_data/part_1/may_july_chunk_11.csv.gz
# /Users/mahdi/repos/USC_hacketon/nl2sql_agent/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/mahdi/repos/USC_hacketon/nl2sql_agent/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/mahdi/repos/USC_hacketon/nl2sql_agent/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/mahdi/repos/USC_hacketon/nl2sql_agent/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# 📊 Column Analysis Report
# ====================================================================================================
#
# 📌 Column: id
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: int64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 50000
#    • Sample Values: 1801321015319896315, 1801321014204178511, 1801321014040686814
#
# 📈 Numeric Statistics:
#    • Min: 1,801,287,601,271,271,680.00
#    • Max: 1,801,321,015,319,896,320.00
#    • Mean: 1,801,304,750,555,860,992.00
#    • Median: 1,801,305,189,049,210,880.00
#
# 📌 Column: text
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 49669
#    • Sample Values: @BidenHQ Thank you, PM Meloni, for shepherding our "lost little POTUS" back to the herd.
# I'm so sorry you and Macron, etc., have to provide nursing care Biden
# This is REALLY not in your job description., @MuskUniverseUsa 9, @BidenHQ Lmfao. Biden has fallen down 17 times this year. You’re finding the one video where it was raining and he was wearing dress shoes down a metal ramp 😂😂😂 you guy have nothing on him.
# Go find the cheer he got from those young cadets.  It was deafening
#
# 📝 String Statistics:
#    • Average Length: 146.0
#    • Max Length: 965
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - @Ashy_slashee Joe Biden: 19 occurrences
#      - @Mollyploofkins MAGA: 17 occurrences
#      - @Diane_Jackson7 Biden: 10 occurrences
#
# 📌 Column: url
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 50000
#    • Sample Values: https://twitter.com/jeannieCsylvia/status/1801321015319896315, https://twitter.com/ConservativeRTJ/status/1801321014204178511, https://twitter.com/CostaGlaropoulo/status/1801321014040686814
#
# 📝 String Statistics:
#    • Average Length: 58.6
#    • Max Length: 62
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - https://twitter.com/jeannieCsylvia/status/1801321015319896315: 1 occurrences
#      - https://twitter.com/911covfefe/status/1801299481444684027: 1 occurrences
#      - https://twitter.com/dontquitRgiveup/status/1801299492693540925: 1 occurrences
#
# 📌 Column: epoch
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: int64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 7509
#    • Sample Values: 1718303371, 1718303371, 1718303371
#
# 📈 Numeric Statistics:
#    • Min: 1,718,295,405.00
#    • Max: 1,718,303,371.00
#    • Mean: 1,718,299,493.31
#    • Median: 1,718,299,598.00
#
# 📌 Column: media
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 6586
#    • Sample Values: [], [], []
#
# 📝 String Statistics:
#    • Average Length: 218.5
#    • Max Length: 28577
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - []: 43,409 occurrences
#      - [{'display_url': 'pic.x.com/hi0cgfobpr', 'expanded_url': 'https://twitter.com/marceyplay/status/1759020287541026835/photo/1', 'id_str': '1759020176131964928', 'indices': [102, 125], 'media_key': '3_1759020176131964928', 'media_url_https': 'https://pbs.twimg.com/media/GGlLh88XQAALCTp.jpg', 'source_status_id_str': '1759020287541026835', 'source_user_id_str': '29287324', 'type': 'photo', 'url': 'https://t.co/hI0CgFoBpr', 'ext_media_availability': {'status': 'Available'}, 'features': {'large': {'faces': []}, 'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}}, 'sizes': {'large': {'h': 1560, 'w': 720, 'resize': 'fit'}, 'medium': {'h': 1200, 'w': 554, 'resize': 'fit'}, 'small': {'h': 680, 'w': 314, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}, 'original_info': {'height': 1560, 'width': 720, 'focus_rects': [{'x': 0, 'y': 927, 'w': 720, 'h': 403}, {'x': 0, 'y': 768, 'w': 720, 'h': 720}, {'x': 0, 'y': 718, 'w': 720, 'h': 821}, {'x': 0, 'y': 120, 'w': 720, 'h': 1440}, {'x': 0, 'y': 0, 'w': 720, 'h': 1560}]}, 'media_results': {'result': {'media_key': '3_1759020176131964928'}}}]: 3 occurrences
#      - [{'display_url': 'pic.x.com/hi0cgfobpr', 'expanded_url': 'https://twitter.com/marceyplay/status/1759020287541026835/photo/1', 'id_str': '1759020176131964928', 'indices': [99, 122], 'media_key': '3_1759020176131964928', 'media_url_https': 'https://pbs.twimg.com/media/GGlLh88XQAALCTp.jpg', 'source_status_id_str': '1759020287541026835', 'source_user_id_str': '29287324', 'type': 'photo', 'url': 'https://t.co/hI0CgFoBpr', 'ext_media_availability': {'status': 'Available'}, 'features': {'large': {'faces': []}, 'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}}, 'sizes': {'large': {'h': 1560, 'w': 720, 'resize': 'fit'}, 'medium': {'h': 1200, 'w': 554, 'resize': 'fit'}, 'small': {'h': 680, 'w': 314, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}, 'original_info': {'height': 1560, 'width': 720, 'focus_rects': [{'x': 0, 'y': 927, 'w': 720, 'h': 403}, {'x': 0, 'y': 768, 'w': 720, 'h': 720}, {'x': 0, 'y': 718, 'w': 720, 'h': 821}, {'x': 0, 'y': 120, 'w': 720, 'h': 1440}, {'x': 0, 'y': 0, 'w': 720, 'h': 1560}]}, 'media_results': {'result': {'media_key': '3_1759020176131964928'}}}]: 2 occurrences
#
# 📌 Column: retweetedTweet
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: bool
#    • Null Values: 0 (0.0%)
#    • Unique Values: 1
#    • Sample Values: False, False, False
#
# 📌 Column: retweetedTweetID
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 50000 (100.0%)
#    • Unique Values: 0
#    • Sample Values:
#
# 📈 Numeric Statistics:
#    • Min: nan
#    • Max: nan
#    • Mean: nan
#    • Median: nan
#
# 📌 Column: retweetedUserID
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 50000 (100.0%)
#    • Unique Values: 0
#    • Sample Values:
#
# 📈 Numeric Statistics:
#    • Min: nan
#    • Max: nan
#    • Mean: nan
#    • Median: nan
#
# 📌 Column: id_str
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: int64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 50000
#    • Sample Values: 1801321015319896315, 1801321014204178511, 1801321014040686814
#
# 📈 Numeric Statistics:
#    • Min: 1,801,287,601,271,271,680.00
#    • Max: 1,801,321,015,319,896,320.00
#    • Mean: 1,801,304,750,555,860,992.00
#    • Median: 1,801,305,189,049,210,880.00
#
# 📌 Column: lang
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 51
#    • Sample Values: en, und, en
#
# 📝 String Statistics:
#    • Average Length: 2.0
#    • Max Length: 3
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - en: 44,384 occurrences
#      - qme: 1,358 occurrences
#      - es: 1,107 occurrences
#
# 📌 Column: rawContent
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 49669
#    • Sample Values: @BidenHQ Thank you, PM Meloni, for shepherding our "lost little POTUS" back to the herd.
# I'm so sorry you and Macron, etc., have to provide nursing care Biden
# This is REALLY not in your job description., @MuskUniverseUsa 9, @BidenHQ Lmfao. Biden has fallen down 17 times this year. You’re finding the one video where it was raining and he was wearing dress shoes down a metal ramp 😂😂😂 you guy have nothing on him.
# Go find the cheer he got from those young cadets.  It was deafening
#
# 📝 String Statistics:
#    • Average Length: 146.0
#    • Max Length: 965
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - @Ashy_slashee Joe Biden: 19 occurrences
#      - @Mollyploofkins MAGA: 17 occurrences
#      - @Diane_Jackson7 Biden: 10 occurrences
#
# 📌 Column: replyCount
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: int64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 271
#    • Sample Values: 0, 0, 0
#
# 📈 Numeric Statistics:
#    • Min: 0.00
#    • Max: 12,586.00
#    • Mean: 3.93
#    • Median: 0.00
#
# 📌 Column: retweetCount
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: int64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 376
#    • Sample Values: 0, 0, 0
#
# 📈 Numeric Statistics:
#    • Min: 0.00
#    • Max: 16,888.00
#    • Mean: 7.36
#    • Median: 0.00
#
# 📌 Column: likeCount
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 661
#    • Sample Values: 0.0, 0.0, 0.0
#
# 📈 Numeric Statistics:
#    • Min: 0.00
#    • Max: 102,539.00
#    • Mean: 34.02
#    • Median: 0.00
#
# 📌 Column: quoteCount
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 152
#    • Sample Values: 0.0, 0.0, 0.0
#
# 📈 Numeric Statistics:
#    • Min: 0.00
#    • Max: 7,195.00
#    • Mean: 1.67
#    • Median: 0.00
#
# 📌 Column: conversationId
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 25392
#    • Sample Values: 1.8012927208809472e+18, 1.8012518212034033e+18, 1.8012927208809472e+18
#
# 📈 Numeric Statistics:
#    • Min: 171,789,989,678,559,232.00
#    • Max: 1,801,321,008,655,171,840.00
#    • Mean: 1,799,831,077,806,680,320.00
#    • Median: 1,801,283,514,236,633,088.00
#
# 📌 Column: conversationIdStr
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 0 (0.0%)
#    • Unique Values: 25392
#    • Sample Values: 1.8012927208809472e+18, 1.8012518212034033e+18, 1.8012927208809472e+18
#
# 📈 Numeric Statistics:
#    • Min: 171,789,989,678,559,232.00
#    • Max: 1,801,321,008,655,171,840.00
#    • Mean: 1,799,831,077,806,680,320.00
#    • Median: 1,801,283,514,236,633,088.00
#
# 📌 Column: hashtags
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 3337
#    • Sample Values: [], [], []
#
# 📝 String Statistics:
#    • Average Length: 9.9
#    • Max Length: 1454
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - []: 46,322 occurrences
#      - [{'indices': [31, 50], 'text': 'BeachMaripilyParty'}]: 22 occurrences
#      - [{'indices': [132, 140], 'text': 'FoxNews'}]: 13 occurrences
#
# 📌 Column: mentionedUsers
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 16363
#    • Sample Values: [], [{'id_str': '1711997156310355968', 'name': 'Elon Musk (Parody)', 'screen_name': 'MuskUniverseUsa', 'indices': [0, 16]}], []
#
# 📝 String Statistics:
#    • Average Length: 139.2
#    • Max Length: 5674
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - []: 12,813 occurrences
#      - [{'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'indices': [0, 9]}]: 566 occurrences
#      - [{'id_str': '11134252', 'name': 'GOP', 'screen_name': 'GOP', 'indices': [0, 4]}]: 528 occurrences
#
# 📌 Column: links
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 5252
#    • Sample Values: [], [], []
#
# 📝 String Statistics:
#    • Average Length: 24.0
#    • Max Length: 993
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - []: 44,706 occurrences
#      - [{'display_url': 'x.com/BenjaminPDixon…', 'expanded_url': 'https://x.com/BenjaminPDixon/status/1801305796698865741', 'url': 'https://t.co/xuaMtkdXKZ', 'indices': [128, 151]}]: 5 occurrences
#      - [{'display_url': 'OnlineColumnist.com', 'expanded_url': 'http://OnlineColumnist.com', 'url': 'https://t.co/19Exr4IAnq', 'indices': [0, 23]}]: 4 occurrences
#
# 📌 Column: viewCount
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 3036
#    • Sample Values: {'count': '11', 'state': 'EnabledWithCount'}, {'count': '2', 'state': 'EnabledWithCount'}, {'count': '26', 'state': 'EnabledWithCount'}
#
# 📝 String Statistics:
#    • Average Length: 43.5
#    • Max Length: 50
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - {'count': '3', 'state': 'EnabledWithCount'}: 2,356 occurrences
#      - {'count': '4', 'state': 'EnabledWithCount'}: 2,344 occurrences
#      - {'count': '5', 'state': 'EnabledWithCount'}: 2,275 occurrences
#
# 📌 Column: quotedTweet
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: bool
#    • Null Values: 0 (0.0%)
#    • Unique Values: 2
#    • Sample Values: False, False, False
#
# 📌 Column: in_reply_to_screen_name
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 13517 (27.0%)
#    • Unique Values: 12108
#    • Sample Values: KamalaHQ, MuskUniverseUsa, KamalaHQ
#
# 📝 String Statistics:
#    • Average Length: 11.1
#    • Max Length: 15
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - GOP: 644 occurrences
#      - JoeBiden: 581 occurrences
#      - KamalaHQ: 444 occurrences
#
# 📌 Column: in_reply_to_status_id_str
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 14065 (28.1%)
#    • Unique Values: 18350
#    • Sample Values: 1.8012927208809472e+18, 1.8012518212034033e+18, 1.8012927208809472e+18
#
# 📈 Numeric Statistics:
#    • Min: 171,789,989,678,559,232.00
#    • Max: 1,801,320,828,312,686,848.00
#    • Mean: 1,800,393,339,846,704,640.00
#    • Median: 1,801,266,828,775,223,552.00
#
# 📌 Column: in_reply_to_user_id_str
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 13517 (27.0%)
#    • Unique Values: 12104
#    • Sample Values: 3315264553.0, 1.711997156310356e+18, 3315264553.0
#
# 📈 Numeric Statistics:
#    • Min: 61,743.00
#    • Max: 1,801,310,545,053,691,904.00
#    • Mean: 641,219,788,631,040,128.00
#    • Median: 4,018,888,580.00
#
# 📌 Column: location
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 50000 (100.0%)
#    • Unique Values: 0
#    • Sample Values:
#
# 📈 Numeric Statistics:
#    • Min: nan
#    • Max: nan
#    • Mean: nan
#    • Median: nan
#
# 📌 Column: cash_app_handle
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 50000 (100.0%)
#    • Unique Values: 0
#    • Sample Values:
#
# 📈 Numeric Statistics:
#    • Min: nan
#    • Max: nan
#    • Mean: nan
#    • Median: nan
#
# 📌 Column: user
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: object
#    • Null Values: 0 (0.0%)
#    • Unique Values: 41478
#    • Sample Values: {'id': 1595045671324844033, 'id_str': '1595045671324844033', 'url': 'https://twitter.com/Jeannie Sylvia', 'username': 'Jeannie Sylvia', 'rawDescription': '', 'created': datetime.datetime(2022, 11, 22, 13, 25, 16, tzinfo=datetime.timezone.utc), 'followersCount': 216, 'friendsCount': 366, 'statusesCount': 4166, 'favouritesCount': 9818, 'listedCount': 0, 'mediaCount': 161, 'location': 'Norfolk, VA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1595046462441885698/HyNmRZq9_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}, {'id': 1524051593498435587, 'id_str': '1524051593498435587', 'url': 'https://twitter.com/Booker RT J', 'username': 'Booker RT J', 'rawDescription': '', 'created': datetime.datetime(2022, 5, 10, 15, 40, 47, tzinfo=datetime.timezone.utc), 'followersCount': 101, 'friendsCount': 131, 'statusesCount': 55, 'favouritesCount': 2093, 'listedCount': 0, 'mediaCount': 0, 'location': 'Illinois, USA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1526979312112619520/7_G8vEhf_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}, {'id': 1518708043902562304, 'id_str': '1518708043902562304', 'url': 'https://twitter.com/Costa G', 'username': 'Costa G', 'rawDescription': 'I am a Son, a Husband, a Dad, a business owner and a Lover of The USA. 🇺🇸 Bring it Back from these Liberals', 'created': datetime.datetime(2022, 4, 25, 21, 46, 53, tzinfo=datetime.timezone.utc), 'followersCount': 1770, 'friendsCount': 1433, 'statusesCount': 27648, 'favouritesCount': 8663, 'listedCount': 29, 'mediaCount': 14458, 'location': 'Mansfield, MA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1809757878393401346/PjpQBI1__normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}
#
# 📝 String Statistics:
#    • Average Length: 711.5
#    • Max Length: 1043
#    • Contains Numbers: ✗
#    • Most Common Values:
#      - {'id': 52480896, 'id_str': '52480896', 'url': 'https://twitter.com/Martha - not a nerd', 'username': 'Martha - not a nerd', 'rawDescription': 'history nut, pit bull mum, crafter, pagan, police, nerd, fan of fantasy novels and Trek, and a sarcastic autistic and adhd, love living in Montana- vote blue', 'created': datetime.datetime(2009, 6, 30, 18, 48, 46, tzinfo=datetime.timezone.utc), 'followersCount': 821, 'friendsCount': 2375, 'statusesCount': 51095, 'favouritesCount': 3428, 'listedCount': 3, 'mediaCount': 5030, 'location': 'Montana, USA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1801021060009414656/2yMflztQ_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}: 40 occurrences
#      - {'id': 1762100801151889408, 'id_str': '1762100801151889408', 'url': 'https://twitter.com/MAGA9241', 'username': 'MAGA9241', 'rawDescription': 'UltraMAGA 2016, 2020, 2024, #1A, #2A, NRA, Old fart, Back the Veteran, Law Enforcement Officers, Rule of Law, Constitution!, Member of We The People!, "Deadeye"', 'created': datetime.datetime(2024, 2, 26, 13, 2, 44, tzinfo=datetime.timezone.utc), 'followersCount': 638, 'friendsCount': 566, 'statusesCount': 8185, 'favouritesCount': 3021, 'listedCount': 0, 'mediaCount': 25, 'location': 'New Jersey, USA', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1762115821101346816/XTJN6QoC_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': False, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}: 34 occurrences
#      - {'id': 2582189852, 'id_str': '2582189852', 'url': 'https://twitter.com/Conservative Box', 'username': 'Conservative Box', 'rawDescription': 'https://t.co/6WicRJTzkv', 'created': datetime.datetime(2014, 6, 22, 12, 57, 57, tzinfo=datetime.timezone.utc), 'followersCount': 7668, 'friendsCount': 5567, 'statusesCount': 63935, 'favouritesCount': 26302, 'listedCount': 92, 'mediaCount': 509, 'location': '', 'profileImageUrl': 'https://pbs.twimg.com/profile_images/1516015069590663171/nwzhTYIp_normal.jpg', 'profileBannerUrl': 'PW', 'protected': 'PW', 'verified': False, 'blue': True, 'blueType': None, 'descriptionLinks': ['PW'], '_type': 'PW'}: 32 occurrences
#
# 📌 Column: date
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 50000 (100.0%)
#    • Unique Values: 0
#    • Sample Values:
#
# 📈 Numeric Statistics:
#    • Min: nan
#    • Max: nan
#    • Mean: nan
#    • Median: nan
#
# 📌 Column: _type
# ────────────────────────────────────────────────────────────────────────────────
# 📋 Basic Information:
#    • Type: float64
#    • Null Values: 50000 (100.0%)
#    • Unique Values: 0
#    • Sample Values:
#
# 📈 Numeric Statistics:
#    • Min: nan
#    • Max: nan
#    • Mean: nan
#    • Median: nan
# /Users/mahdi/repos/USC_hacketon/nl2sql_agent/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /Users/mahdi/repos/USC_hacketon/nl2sql_agent/venv/lib/python3.11/site-packages/numpy/lib/_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# ### Connect to and analyze tweets Database

# %%
def print_table_schema(db_path="tweets2.duckdb"):
    """
    Connect to tweets2.duckdb and print schema and column information.
    First lists available tables, then prints schema for each table.
    
    Args:
        db_path (str): Path to the DuckDB database file
    """
    try:
        # Connect to database
        with duckdb.connect(db_path) as con:
            # Get list of tables
            tables_query = "SELECT * FROM sqlite_master WHERE type='table'"
            tables = con.execute(tables_query).fetchdf()
            
            if len(tables) == 0:
                print("No tables found in the database.")
                return
                
            print("\nAvailable tables:")
            for _, row in tables.iterrows():
                table_name = row['name']
                print(f"\n{'='*80}")
                print(f"Table: {table_name}")
                
                # Get schema information
                schema_query = f"DESCRIBE {table_name}"
                schema_info = con.execute(schema_query).fetchdf()
                
                # Get row count
                row_count = con.execute(f"SELECT COUNT(*) FROM {table_name}").fetchone()[0]
                
                # Get distinct counts for each column
                distinct_counts = {}
                for col in schema_info['column_name']:
                    query = f"SELECT COUNT(DISTINCT {col}) FROM {table_name}"
                    distinct_counts[col] = con.execute(query).fetchone()[0]
                
                # Print results
                print(f"Total Rows: {row_count:,}")
                print("\nColumn Information:")
                print("-" * 80)
                print(f"{'Column Name':<30} {'Data Type':<20} {'Distinct Values':<15}")
                print("-" * 80)
                
                for _, row in schema_info.iterrows():
                    col_name = row['column_name']
                    print(f"{col_name:<30} {row['column_type']:<20} {distinct_counts[col_name]:,}")
                
    except Exception as e:
        print(f"Error: {str(e)}")

# %%
print_table_schema()
# Out:
# Available tables:
#
# ================================================================================
# Table: tweets
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Total Rows: 34,761,518
#
# Column Information:
# --------------------------------------------------------------------------------
# Column Name                    Data Type            Distinct Values
# --------------------------------------------------------------------------------
# id                             VARCHAR              32,285,002
# text                           VARCHAR              31,056,384
# url                            VARCHAR              32,144,972
# timestamp                      TIMESTAMP            7,195,185
# media                          VARCHAR              3,705,349
# retweetedTweet                 BOOLEAN              2
# retweetedTweetID               VARCHAR              38,261
# retweetedUserID                VARCHAR              12,727
# lang                           VARCHAR              101
# replyCount                     BIGINT               10,499
# retweetCount                   BIGINT               20,391
# likeCount                      BIGINT               43,605
# quoteCount                     BIGINT               3,946
# conversationId                 VARCHAR              13,950,578
# conversationIdStr              VARCHAR              13,906,577
# hashtags                       VARCHAR              1,668,609
# mentionedUsers                 VARCHAR              5,847,973
# links                          VARCHAR              3,162,293
# viewCount                      BIGINT               179,056
# quotedTweet                    BOOLEAN              2
# location                       VARCHAR              552,553
# cash_app_handle                VARCHAR              1
# username                       VARCHAR              3,408,018
# bio                            VARCHAR              2,789,294
# followersCount                 BIGINT               511,524
# verified                       BOOLEAN              1

# %% [markdown]
# ### NULL Value Statistics on tweets database

# %%
def analyze_null_values(db_path="tweets2.duckdb"):
    """
    Analyze null values in each column of all tables in the DuckDB database.
    
    Args:
        db_path (str): Path to the DuckDB database file
    """
    import duckdb
    from tabulate import tabulate
    
    try:
        with duckdb.connect(db_path) as con:
            # Get list of tables
            tables = con.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchdf()
            
            for _, row in tables.iterrows():
                table_name = row['name']
                print(f"\n{'='*80}")
                print(f"Table: {table_name}")
                
                # Get column names
                columns = con.execute(f"DESCRIBE {table_name}").fetchdf()['column_name'].tolist()
                
                # Calculate null statistics for each column
                null_stats = []
                for col in columns:
                    query = f"""
                    SELECT 
                        '{col}' as column_name,
                        COUNT(*) as total_rows,
                        COUNT({col}) as non_null_count,
                        COUNT(*) - COUNT({col}) as null_count,
                        ROUND(100.0 * (COUNT(*) - COUNT({col})) / COUNT(*), 2) as null_percentage
                    FROM {table_name}
                    """
                    stats = con.execute(query).fetchdf().iloc[0]
                    null_stats.append(stats)
                
                # Convert to DataFrame for nice display
                import pandas as pd
                stats_df = pd.DataFrame(null_stats)
                
                # Sort by null percentage descending
                stats_df = stats_df.sort_values('null_percentage', ascending=False)
                
                # Print formatted table
                print("\nNull Value Analysis:")
                print(tabulate(stats_df, headers='keys', tablefmt='pretty', showindex=False))
                
    except Exception as e:
        print(f"Error: {str(e)}")

# Run the analysis
analyze_null_values()
# Out:
# ================================================================================
# Table: tweets
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Null Value Analysis:
# +-------------------+------------+----------------+------------+-----------------+
# |    column_name    | total_rows | non_null_count | null_count | null_percentage |
# +-------------------+------------+----------------+------------+-----------------+
# |  cash_app_handle  |  34761518  |    1765592     |  32995926  |      94.92      |
# |     verified      |  34761518  |    32715133    |  2046385   |      5.89       |
# |        bio        |  34761518  |    32715133    |  2046385   |      5.89       |
# |     username      |  34761518  |    32715133    |  2046385   |      5.89       |
# |     location      |  34761518  |    32715133    |  2046385   |      5.89       |
# |       text        |  34761518  |    33262431    |  1499087   |      4.31       |
# |     timestamp     |  34761518  |    33262437    |  1499081   |      4.31       |
# |       media       |  34761518  |    33262478    |  1499040   |      4.31       |
# |       lang        |  34761518  |    33262483    |  1499035   |      4.31       |
# |        url        |  34761518  |    33551973    |  1209545   |      3.48       |
# |        id         |  34761518  |    33701844    |  1059674   |      3.05       |
# |     likeCount     |  34761518  |    34761518    |     0      |       0.0       |
# |    quoteCount     |  34761518  |    34761518    |     0      |       0.0       |
# |   retweetCount    |  34761518  |    34761518    |     0      |       0.0       |
# | conversationIdStr |  34761518  |    34761518    |     0      |       0.0       |
# |     hashtags      |  34761518  |    34761518    |     0      |       0.0       |
# |  mentionedUsers   |  34761518  |    34761518    |     0      |       0.0       |
# |       links       |  34761518  |    34761518    |     0      |       0.0       |
# |     viewCount     |  34761518  |    34761518    |     0      |       0.0       |
# |    quotedTweet    |  34761518  |    34761518    |     0      |       0.0       |
# |    replyCount     |  34761518  |    34761518    |     0      |       0.0       |
# |  retweetedUserID  |  34761518  |    34761518    |     0      |       0.0       |
# | retweetedTweetID  |  34761518  |    34761518    |     0      |       0.0       |
# |  retweetedTweet   |  34761518  |    34761518    |     0      |       0.0       |
# |  followersCount   |  34761518  |    34761518    |     0      |       0.0       |
# |  conversationId   |  34761518  |    34761518    |     0      |       0.0       |
# +-------------------+------------+----------------+------------+-----------------+

# %% [markdown]
# ### Sampling from database at random

# %%
def print_random_rows(db_path="tweets2.duckdb", n_rows=10):
    """
    Print random rows from each table in the database in a nicely formatted table.
    
    Args:
        db_path (str): Path to the DuckDB database file
        n_rows (int): Number of random rows to sample
    """
    import duckdb
    from tabulate import tabulate
    
    try:
        with duckdb.connect(db_path) as con:
            # Get list of tables
            tables = con.execute("SELECT name FROM sqlite_master WHERE type='table'").fetchdf()
            
            for _, row in tables.iterrows():
                table_name = row['name']
                print(f"\n{'='*80}")
                print(f"Table: {table_name}")
                print(f"Random {n_rows} rows:")
                
                # Query random rows
                query = f"""
                SELECT *
                FROM {table_name}
                ORDER BY RANDOM()
                LIMIT {n_rows}
                """
                sample_df = con.execute(query).fetchdf()
                
                # Print formatted table
                print(tabulate(sample_df, headers='keys', tablefmt='pretty', showindex=False))
                
    except Exception as e:
        print(f"Error: {str(e)}")

# Run the analysis
print_random_rows()
# Out:
# ================================================================================
# Table: tweets
# Random 10 rows:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# +-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+---------------------+----------------------------------------------+----------------+------------------+-----------------+------+------------+--------------+-----------+------------+------------------------+------------------------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------------+------------------------+-----------------+------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------+
# |          id           |                                                                                                                                                                         text                                                                                                                                                                         |                             url                              |      timestamp      |                    media                     | retweetedTweet | retweetedTweetID | retweetedUserID | lang | replyCount | retweetCount | likeCount | quoteCount |     conversationId     |   conversationIdStr    | hashtags |                                                                                                                                                                                                              mentionedUsers                                                                                                                                                                                                               |                                                                                                                              links                                                                                                                              | viewCount | quotedTweet |        location        | cash_app_handle |        username        |                                                                               bio                                                                                | followersCount | verified |
# +-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+---------------------+----------------------------------------------+----------------+------------------+-----------------+------+------------+--------------+-----------+------------+------------------------+------------------------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------------+------------------------+-----------------+------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------+
# |  1811541725485154387  |                                                                     @Charles_Lister I'm not saying there isn't an issue here, but deliberately cutting the video just before Biden catches his mistake, corrects himself, and cracks a joke isn't really a fair representation.                                                                      | https://twitter.com/HereLiesJeff/status/1811541725485154387  | 2024-07-11 23:22:58 |                      []                      |     False      |       nan        |       nan       |  en  |     11     |      2       |    58     |     0      |  1811518803576000729   |  1811518803576000729   |    []    |                                                                                                                                                                 [{'id_str': '469509327', 'name': 'Charles Lister', 'screen_name': 'Charles_Lister', 'indices': [0, 15]}]                                                                                                                                                                  |                                                                                                                               []                                                                                                                                |   5740    |    False    |   Blackpool, England   |                 |     Jeff Simpkins      |              🇬🇧 COO at @RSVGG | Chair of @TheUKETC | Ex Police Sgt in Lancashire | Previous @Rainbow6Game competitive player | All views are my own              |      2682      |  False   |
# |  1838200022418010404  |                                                                                                                                              @BetteMidler Someone forgot about the Hunter Biden laptop.                                                                                                                                              | https://twitter.com/le_complotiss/status/1838200022418010404 | 2024-09-23 12:53:32 |                      []                      |     False      |       nan        |       nan       |  en  |     0      |      0       |     0     |     0      |  1837910884750184784   | 1.8379108847501847e+18 |    []    |                                                                                                                                                                    [{'id_str': '139823781', 'name': 'bettemidler', 'screen_name': 'BetteMidler', 'indices': [0, 12]}]                                                                                                                                                                     |                                                                                                                               []                                                                                                                                |    11     |    False    |                        |                 |     LE COMPLOTISSS     |                                                                                                                                                                  |      188       |  False   |
# |  1792163714130440332  |                                                                                          @RealHickory They will jack him full of drugs like they did for the state of the union. When he is loaded his eyes bug out, a blank stare and he will never blink.                                                                                          |  https://twitter.com/tomsom5151/status/1792163714130440332   | 2024-05-19 12:01:40 | {'photos': [], 'videos': [], 'animated': []} |     False      |       nan        |       nan       |  en  |     0      |      0       |     1     |     0      | 1.7918423647151352e+18 |  1791842364715135137   |    []    |                                                                                                                                 [{'id': 1565471830793756673, 'id_str': '1565471830793756673', 'username': 'RealHickory', 'displayname': 'Mike Engleman🇺🇲', '_type': 'snscrape.modules.twitter.UserRef'}]                                                                                                                                  |                                                                                                                               []                                                                                                                                |     3     |    False    |                        |                 |       tomsom5151       |                                                                                                                                                                  |      483       |  False   |
# |  1811065321769357489  |                                                             @solosmommy @valhalla0268 @MiraSorvino There's plenty of left leaning think tanks that would love to end capitalism among other crazy ideas, that doesn't mean Joe Biden wants to. These fear mongering tactics are stupid.                                                              | https://twitter.com/118Remi49585/status/1811065321769357489  | 2024-07-10 15:49:55 |                      []                      |     False      |       nan        |       nan       |  en  |     1      |      0       |     2     |     0      |  1811013002503573929   |  1811013002503573929   |    []    |                                                            [{'id_str': '2319343795', 'name': 'PNW Mama', 'screen_name': 'solosmommy', 'indices': [0, 11]}, {'id_str': '831311003879108610', 'name': 'Amelia ✝️🇺🇸🐕', 'screen_name': 'valhalla0268', 'indices': [12, 25]}, {'id_str': '613088225', 'name': 'Mira Sorvino', 'screen_name': 'MiraSorvino', 'indices': [26, 38]}]                                                             |                                                                                                                               []                                                                                                                                |    108    |    False    |                        |                 |      Jack Burton       |                                                                                                                                                                  |       27       |  False   |
# |  1815988387959972096  |                                                                                                                                                   @wrong_speak Lied about the health of Joe Biden.                                                                                                                                                   |  https://twitter.com/matt_quietk/status/1815988387959972049  | 2024-07-24 05:52:25 |                      []                      |     False      |       nan        |       nan       |  en  |     0      |      0       |     0     |     0      | 1.8157675771985267e+18 |  1815767577198526720   |    []    |                                                                                                                                                     [{'id_str': '1297839315326836738', 'name': 'Adam B. Coleman, Le Based Black', 'screen_name': 'wrong_speak', 'indices': [0, 12]}]                                                                                                                                                      |                                                                                                                               []                                                                                                                                |    22     |    False    |   Pennsylvania, USA    |                 |          Matt          |                                                                                                                                                                  |       12       |  False   |
# |  1811584053579034726  |                                                                       @Curry4USA @kayleighmcenany Absolutely disgusting. What really kills me is the DEMS are insulting the American public by “gaslighting” the cognitive deficiencies in Biden, as if we can’t see or hear.                                                                        |    https://twitter.com/BatzerJ/status/1811584053579034726    | 2024-07-12 02:11:10 |                      []                      |     False      |       nan        |       nan       |  en  |     0      |      0       |     2     |     0      |  1811551369456705842   |  1811551369456705842   |    []    |                                                                                                        [{'id_str': '1585805950128197632', 'name': '🇺🇸AmericaFirst🇺🇸', 'screen_name': 'Curry4USA', 'indices': [0, 10]}, {'id_str': '259001548', 'name': 'Kayleigh McEnany', 'screen_name': 'kayleighmcenany', 'indices': [11, 27]}]                                                                                                        |                                                                                                                               []                                                                                                                                |    23     |    False    |     Broomfield, CO     |                 |      jill Batzer       |                                                                                                                                                                  |       31       |  False   |
# |  1812073557100249258  |                                                                                                           Democrat lawmakers who called for Biden to step aside in the race refused to call for him to step down from leading the country.                                                                                                           |   https://twitter.com/tgradous/status/1812073557100249258    | 2024-07-13 10:36:17 |                      PW                      |     False      |       nan        |       nan       |  en  |     0      |      0       |     1     |     0      |  1812073557100249258   |  1812073557100249258   |    []    |                                                                                                              [{'id_str': '2309156352', 'name': 'Brianna Lyman', 'screen_name': 'briannalyman2', 'indices': [135, 149]}, {'id_str': '1408003598', 'name': 'The Federalist', 'screen_name': 'FDRLST', 'indices': [151, 158]}]                                                                                                               | [{'display_url': 'thefederalist.com/2024/07/12/dem…', 'expanded_url': 'https://thefederalist.com/2024/07/12/democrats-calling-for-biden-to-drop-out-refuse-to-say-he-should-step-down-as-president/', 'url': 'https://t.co/OdS2YGqSg1', 'indices': [161, 184]}] |     0     |    False    | Home of The MASTERS ⛳️ |       PW        |      Tim Gradous       | Horse trainer/Hay farmer, Old Saddle Bronc Rider - Trying to be as good as my 🐶 &🐴 think I am. Democracy killed The Republic. Married #HaySeedHick #JesusSaves |     59037      |  False   |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                                                                                                                  |                |          |
# |                       |                                                                                                                                                                  BY: ⁦@briannalyman2                                                                                                                                                                  |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                                                                                                                  |                |          |
# |                       |                                                                                                                                                           ⁦@FDRLST⁩  https://t.co/OdS2YGqSg1                                                                                                                                                           |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                                                                                                                  |                |          |
# |  1812742097599897615  |                                         @hodgetwins The left has been doing this for years in relation to inconsequential things that hurt their feelings. Now they think they get a pass for condoning an assassination attempt on one of the greatest human beings ever. No way!  Name and Shame them all!                                         | https://twitter.com/TrumplicanLex/status/1812742097599897615 | 2024-07-15 06:52:49 |                      []                      |     False      |       nan        |       nan       |  en  |     0      |      1       |     2     |     0      |  1812671621473178032   |  1812671621473178032   |    []    |                                                                                                                                                                      [{'id_str': '18584875', 'name': 'Hodgetwins', 'screen_name': 'hodgetwins', 'indices': [0, 11]}]                                                                                                                                                                      |                                                                                                                               []                                                                                                                                |    48     |    False    |        Florida         |                 | 🇺🇸ULTRA NUCLEAR MAGA🇺🇸 |                                                                          🍊Trump 2024🍊                                                                          |     10496      |  False   |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                        🇺🇸America First!🇺🇸                                                                        |                |          |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                       🚫No More RINOS!🤜🦏                                                                       |                |          |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                                                                                                                  |                |          |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                           LGBFJB!🤡🌏                                                                            |                |          |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                               I FB (Back for Round 4, Thanx Elon!)                                                               |                |          |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                                                                                                                  |                |          |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                  *Trumpy Bear is a Super Hero*                                                                   |                |          |
# |  1787882311041917040  |                                                                                                                                             @Angry_Staffer However, Biden DID shower with his daughter.                                                                                                                                              |  https://twitter.com/GProcustin/status/1787882311041917040   | 2024-05-07 16:28:54 |                      []                      |     False      |       nan        |       nan       |  en  |     0      |      0       |     0     |     0      | 1.787868217584636e+18  |  1787868217584635992   |    []    |                                                                                                                                                            [{'id_str': '848148994102611969', 'name': 'Angry Staffer 🌻', 'screen_name': 'Angry_Staffer', 'indices': [0, 14]}]                                                                                                                                                             |                                                                                                                               []                                                                                                                                |     5     |    False    |                        |                 |   Kamala's knee pad    |                                                   Pro choice I Resist I Antifa I BLM I ESPN I NAACP I BOCA I                                                     |      228       |  False   |
# |                       |                                                                                                                                                                                                                                                                                                                                                      |                                                              |                     |                                              |                |                  |                 |      |            |              |           |            |                        |                        |          |                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                 |           |             |                        |                 |                        |                                                                           CNN I LMNOP                                                                            |                |          |
# | 1.825199282825073e+18 | @newacco64515530 @lifestyleofcs @walepepperpike @JaymalGreen Lol hardly, just a Christian Conservative who believes that everyone has the right to a better life which all stats show we had under Trump. And truly who even needs statistics, I look at how much I’m paying for everything and it’s obvious. It’s easy to claim his accomplishments | https://twitter.com/Momma2amelia/status/1825199282825072931  | 2024-08-18 15:53:14 |                      []                      |     False      |       nan        |       nan       |  en  |     0      |      0       |     0     |     0      | 1.8249896837611525e+18 | 1.8249896837611525e+18 |    []    | [{'id_str': '1331227745037266948', 'name': 'newaccount', 'screen_name': 'newacco64515530', 'indices': [0, 16]}, {'id_str': '750062345787936768', 'name': 'Smith ⚡️', 'screen_name': 'lifestyleofcs', 'indices': [17, 31]}, {'id_str': '1241862031810211841', 'name': 'Adewale', 'screen_name': 'walepepperpike', 'indices': [32, 47]}, {'id_str': '66636747', 'name': "Ja'Mal Green", 'screen_name': 'JaymalGreen', 'indices': [48, 60]}] |                                                                                                                               []                                                                                                                                |     8     |    False    |                        |                 |         Ashley         |                                        Came for the crypto, staying for the politics TRUMP 2024 Christ is King 👑 $Stash                                         |      624       |  False   |
# +-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------+---------------------+----------------------------------------------+----------------+------------------+-----------------+------+------------+--------------+-----------+------------+------------------------+------------------------+----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------+-------------+------------------------+-----------------+------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------+

# %% [markdown]
# ### Statistics on top locations, and userNames

# %%
def analyze_top_user_stats(db_path="tweets2.duckdb", top_n=10):
    """
    Analyze top locations and usernames from the tweets database.
    
    Args:
        db_path (str): Path to the DuckDB database file
        top_n (int): Number of top entries to show
    """
    import duckdb
    from tabulate import tabulate
    
    try:
        with duckdb.connect(db_path) as con:
            # Top Locations Analysis
            location_query = f"""
            SELECT 
                location,
                COUNT(*) as tweet_count,
                COUNT(DISTINCT username) as unique_users,
                ROUND(AVG(replyCount), 2) as avg_replies,
                ROUND(AVG(retweetCount), 2) as avg_retweets,
                ROUND(AVG(likeCount), 2) as avg_likes
            FROM tweets 
            WHERE location IS NOT NULL
            GROUP BY location
            ORDER BY tweet_count DESC
            LIMIT {top_n}
            """
            
            # Top Users Analysis
            users_query = f"""
            SELECT 
                username,
                COUNT(*) as tweet_count,
                COUNT(DISTINCT location) as unique_locations,
                ROUND(AVG(replyCount), 2) as avg_replies,
                ROUND(AVG(retweetCount), 2) as avg_retweets,
                ROUND(AVG(likeCount), 2) as avg_likes,
                ROUND(AVG(LENGTH(text)), 2) as avg_tweet_length
            FROM tweets
            WHERE username IS NOT NULL
            GROUP BY username
            ORDER BY tweet_count DESC
            LIMIT {top_n}
            """
            
            # Execute queries
            top_locations = con.execute(location_query).fetchdf()
            top_users = con.execute(users_query).fetchdf()
            
            # Print results
            print(f"\n{'='*80}")
            print(f"Top {top_n} Locations by Tweet Count")
            print(tabulate(top_locations, headers='keys', tablefmt='pretty', showindex=False))
            
            print(f"\n{'='*80}")
            print(f"Top {top_n} Users by Tweet Count")
            print(tabulate(top_users, headers='keys', tablefmt='pretty', showindex=False))
            
            # Additional Statistics
            print(f"\n{'='*80}")
            print("General Statistics:")
            
            stats_query = """
            SELECT 
                COUNT(DISTINCT location) as total_unique_locations,
                COUNT(DISTINCT username) as total_unique_users,
                ROUND(AVG(replyCount), 2) as overall_avg_replies,
                ROUND(AVG(retweetCount), 2) as overall_avg_retweets,
                ROUND(AVG(likeCount), 2) as overall_avg_likes
            FROM tweets
            """
            
            stats = con.execute(stats_query).fetchdf()
            print(tabulate(stats, headers='keys', tablefmt='pretty', showindex=False))
            
    except Exception as e:
        print(f"Error: {str(e)}")

# Run the analysis
analyze_top_user_stats()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ================================================================================
# Top 10 Locations by Tweet Count
# +-----------------+-------------+--------------+-------------+--------------+-----------+
# |    location     | tweet_count | unique_users | avg_replies | avg_retweets | avg_likes |
# +-----------------+-------------+--------------+-------------+--------------+-----------+
# |                 |  13351190   |   1578490    |    5.14     |    27.67     |   76.18   |
# |  United States  |   916734    |    62331     |    18.07    |     60.6     |  201.73   |
# |       USA       |   489250    |    26627     |    13.63    |    39.33     |  119.89   |
# |  Florida, USA   |   287995    |    18640     |    12.13    |    51.42     |  162.34   |
# |   Texas, USA    |   233727    |    16500     |    14.99    |    36.62     |  100.94   |
# | California, USA |   189954    |    15258     |     9.8     |    23.85     |   39.93   |
# | Washington, DC  |   157711    |    11248     |   164.38    |    218.95    |  1239.49  |
# |      Earth      |   146283    |    13312     |    14.34    |    31.69     |   97.09   |
# | Los Angeles, CA |   133187    |    15199     |    9.65     |     49.5     |  139.96   |
# |      Texas      |   126267    |     7762     |    2.29     |    26.72     |   30.37   |
# +-----------------+-------------+--------------+-------------+--------------+-----------+
#
# ================================================================================
# Top 10 Users by Tweet Count
# +----------------------------------------------------+-------------+------------------+-------------+--------------+-----------+------------------+
# |                      username                      | tweet_count | unique_locations | avg_replies | avg_retweets | avg_likes | avg_tweet_length |
# +----------------------------------------------------+-------------+------------------+-------------+--------------+-----------+------------------+
# | ك&#x624;د خ&#x635;م ن&#x645;ش&#x64A; ن&#x624;ن kag |    36987    |        2         |     0.0     |     0.0      |    0.0    |      73.26       |
# |                       David                        |    25369    |       727        |    0.72     |     4.08     |   9.88    |      118.89      |
# |                        Mike                        |    23213    |       761        |    0.45     |     9.9      |   2.95    |      148.12      |
# |                        MAGA                        |    22860    |        84        |    1.79     |     1.81     |    8.2    |      65.95       |
# |                        John                        |    20478    |       665        |    0.33     |     6.51     |   2.58    |      152.31      |
# |                       Chris                        |    18808    |       789        |    0.71     |     8.57     |   5.18    |      160.58      |
# |                 NahBabyNah #Trump                  |    18410    |        1         |    0.68     |     4.2      |   2.97    |      156.16      |
# |                      Michael                       |    17304    |       698        |     0.3     |     6.41     |   1.86    |      152.41      |
# |                 JKash 🍊MAGA Queen                 |    15432    |        1         |    4.74     |     5.23     |   42.26   |      76.73       |
# |                        maga                        |    14987    |       149        |    0.31     |     0.75     |   4.81    |      62.85       |
# +----------------------------------------------------+-------------+------------------+-------------+--------------+-----------+------------------+
#
# ================================================================================
# General Statistics:
# +------------------------+--------------------+---------------------+----------------------+-------------------+
# | total_unique_locations | total_unique_users | overall_avg_replies | overall_avg_retweets | overall_avg_likes |
# +------------------------+--------------------+---------------------+----------------------+-------------------+
# |        552553.0        |     3408018.0      |   208500324391.0    |   285554591546.28    |  78900920591.58   |
# +------------------------+--------------------+---------------------+----------------------+-------------------+
